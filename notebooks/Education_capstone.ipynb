# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # FMLI231

# %%
fmli231=pd.read_csv(r'C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw22\fmli231.csv')

# %%
#region for Q1
region231=[]
for index, region in fmli231.iterrows():
    if region['REGION']== 1:
        region231.append('Northeast')
    elif region['REGION']== 2:
        region231.append('Midwest')
    elif region['REGION']== 3:
        region231.append('South')
    elif region['REGION']== 4:
        region231.append('West')
    else:
        region231.append('N/A')
fmli231['Region']=region231

# %%
#education for Q1
educlevel231=[]
for index, educ in fmli231.iterrows():
    if educ['HIGH_EDU'] in {0,00,10,11}:
        educlevel231.append('No degree')
    elif educ['HIGH_EDU'] in {12,13}:
        educlevel231.append('High School')
    elif educ['HIGH_EDU'] in {14}:
        educlevel231.append('Associate Degree')
    elif educ['HIGH_EDU'] in {15}:
        educlevel231.append('Bachelor Degree')
    elif educ['HIGH_EDU'] in {16}:
        educlevel231.append('Master Degree')
    elif educ['HIGH_EDU'] in {17}:
        educlevel231.append('Professional/Doctorate Degree')
    else:
        educlevel231.append('N/A')
fmli231['Education level']=educlevel231

# %%
#educ_ref
#education for Q1
educlevel231ref=[]
for index, educ in fmli231.iterrows():
    if educ['EDUC_REF'] in {0,00,1,2,7,10,11}:
        educlevel231ref.append('No degree')
    elif educ['EDUC_REF'] in {3,4,12,13}:
        educlevel231ref.append('High School')
    elif educ['EDUC_REF'] in {14}:
        educlevel231ref.append('Associate Degree')
    elif educ['EDUC_REF'] in {5,6,15}:
        educlevel231ref.append('Bachelor Degree')
    elif educ['EDUC_REF'] in {16}:
        educlevel231ref.append('Master Degree')
    elif educ['EDUC_REF'] in {17}:
        educlevel231ref.append('Professional/Doctorate Degree')
    else:
        educlevel231ref.append('N/A')
fmli231['Education level 2']=educlevel231ref

# %%
# get rid of negative FINCBTAX Q1
#idk why thats there...
#fmli231=fmli231.loc[fmli231['FINCBTAX'] >= 0]

# %%
#Q1
#how much income is available per person in the household
#FINCBTAX= Total amount of family income before taxes in the last 12 months (Collected data)
fmli231['Income per Capita']= fmli231['FINCBTAX']/fmli231['FAM_SIZE']

# %%
#convert FINCBTAX to dollar amount 
#fmli231['Income per Capita'] = fmli231['Income per Capita'].apply(lambda x: "${:,.2f}".format(x))

# %%
#educ order
custom_order=['No degree','High School','Associate Degree','Bachelor Degree', 'Master Degree']

# %%
#order it with the cusom order
fmli231['Education level']=pd.Categorical(fmli231['Education level'], categories= custom_order, ordered=True)

# %%
#order it with the cusom order
fmli231['Education level 2']=pd.Categorical(fmli231['Education level 2'], categories= custom_order, ordered=True)

# %%
fmli231.head()
# Out:
#      NEWID  DIRACC DIRACC_  AGE_REF AGE_REF_  AGE2 AGE2_  AS_COMP1 AS_C_MP1  \
# 0  5011064     1.0       D       87        T   NaN     A         1        D
# 1  5011134     1.0       D       73        D  75.0     D         1        D
# 2  5011244     1.0       D       47        D  44.0     D         1        D
# 3  5011314     1.0       D       82        D   NaN     A         0        D
# 4  5011334     1.0       D       87        T  80.0     D         1        D
#
#    AS_COMP2  ... CHDTXP_  CHDTXPH CHDTXPH_  FFTAXOWE FSTAXOWE  FINATXEM  \
# 0         2  ...       A      NaN        A     -4051      744   57240.2
# 1         1  ...       A      NaN        A     -6600        0   55570.0
# 2         1  ...       A      NaN        A     22325     4892  145383.0
# 3         1  ...       A      NaN        A     -1400        0    8732.0
# 4         1  ...       A      NaN        A     -6600     -148   50555.0
#
#       Region  Education level Education level 2  Income per Capita
# 0      South      High School       High School         659.666667
# 1  Northeast    Master Degree       High School       24485.000000
# 2    Midwest  Bachelor Degree   Bachelor Degree       86300.000000
# 3    Midwest      High School       High School        7332.000000
# 4       West      High School       High School       21903.500000
#
# [5 rows x 822 columns]

# %% [markdown]
# # FMLI232

# %%
fmli232=pd.read_csv(r'C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw23\fmli232.csv')

# %%
#region for Q2
region232=[]
for index, region in fmli232.iterrows():
    if region['REGION']== 1:
        region232.append('Northeast')
    elif region['REGION']== 2:
        region232.append('Midwest')
    elif region['REGION']== 3:
        region232.append('South')
    elif region['REGION']== 4:
        region232.append('West')
    else:
        region232.append('N/A')
fmli232['Region']=region232

# %%
#EDUC FOR Q2
educlevel232=[]
for index, educ in fmli232.iterrows():
    if educ['HIGH_EDU'] in {0,00,10,11}:
        educlevel232.append('No degree')
    elif educ['HIGH_EDU'] in {12,13}:
        educlevel232.append('High School')
    elif educ['HIGH_EDU'] in {14}:
        educlevel232.append('Associate Degree')
    elif educ['HIGH_EDU'] in {15}:
        educlevel232.append('Bachelor Degree')
    elif educ['HIGH_EDU'] in {16}:
        educlevel232.append('Master Degree')
    elif educ['HIGH_EDU'] in {17}:
        educlevel232.append('Professional/Doctorate Degree')
    else:
        educlevel232.append('N/A')
fmli232['Education level']=educlevel232

# %%
#educ_ref
#education for Q2
educlevel232ref=[]
for index, educ in fmli232.iterrows():
    if educ['EDUC_REF'] in {0,00,1,2,7,10,11}:
        educlevel232ref.append('No degree')
    elif educ['EDUC_REF'] in {3,4,12,13}:
        educlevel232ref.append('High School')
    elif educ['EDUC_REF'] in {14}:
        educlevel232ref.append('Associate Degree')
    elif educ['EDUC_REF'] in {5,6,15}:
        educlevel232ref.append('Bachelor Degree')
    elif educ['EDUC_REF'] in {16}:
        educlevel232ref.append('Master Degree')
    elif educ['EDUC_REF'] in {17}:
        educlevel232ref.append('Professional/Doctorate Degree')
    else:
        educlevel232ref.append('N/A')
fmli232['Education level 2']=educlevel232ref

# %%
#get rid of negative FINCBTAX Q2
#idk why thats there...
#fmli232=fmli232.loc[fmli232['FINCBTAX'] >= 0]

# %%
#Q2 calc income per capita
fmli232['Income per Capita']= fmli232['FINCBTAX']/fmli232['FAM_SIZE']

# %%
#convert Income per Capita to dollar amount 
#fmli232['Income per Capita'] = fmli232['Income per Capita'].apply(lambda x: "${:,.2f}".format(x))

# %%
#order it with the cusom order
fmli232['Education level']=pd.Categorical(fmli232['Education level'], categories= custom_order, ordered=True)

# %%
#order it with the cusom order
fmli232['Education level 2']=pd.Categorical(fmli232['Education level'], categories= custom_order, ordered=True)

# %%
fmli232.head()
# Out:
#      NEWID  DIRACC DIRACC_  AGE_REF AGE_REF_  AGE2 AGE2_  AS_COMP1 AS_C_MP1  \
# 0  5090604     1.0       D       74        D  72.0     D         1        D
# 1  5090624     1.0       D       87        T   NaN     A         0        D
# 2  5090634     1.0       D       58        D   NaN     A         0        D
# 3  5090664     1.0       D       55        D  52.0     D         1        D
# 4  5090674     1.0       D       31        D  31.0     D         1        D
#
#    AS_COMP2  ... CHDTXPH  CHDTXPH_ NUM_VET  fftaxowe fstaxowe  FINATXEM  \
# 0         1  ...     NaN         A       1         0        0   40677.0
# 1         1  ...     NaN         A       0         0        0   13787.0
# 2         1  ...     NaN         A       0     20397     7544  107059.0
# 3         1  ...     NaN         A       0      3552     1489   57932.4
# 4         2  ...     NaN         A       0       415        0   36475.0
#
#   Region  Education level Education level 2  Income per Capita
# 0  South    Master Degree     Master Degree       20338.500000
# 1  South      High School       High School       13787.000000
# 2   West  Bachelor Degree   Bachelor Degree      135000.000000
# 3  South      High School       High School           0.000000
# 4   West      High School       High School       12473.333333
#
# [5 rows x 823 columns]

# %% [markdown]
# # FMLI233

# %%
fmli233=pd.read_csv(r'C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw23\fmli233.csv')

# %%
#region for Q3
region233=[]
for index, region in fmli233.iterrows():
    if region['REGION']== 1:
        region233.append('Northeast')
    elif region['REGION']== 2:
        region233.append('Midwest')
    elif region['REGION']== 3:
        region233.append('South')
    elif region['REGION']== 4:
        region233.append('West')
    else:
        region233.append('N/A')
fmli233['Region']=region233

# %%
#EDUC FOR Q3
educlevel233=[]
for index, educ in fmli233.iterrows():
    if educ['HIGH_EDU'] in {0,00,10,11}:
        educlevel233.append('No degree')
    elif educ['HIGH_EDU'] in {12,13}:
        educlevel233.append('High School')
    elif educ['HIGH_EDU'] in {14}:
        educlevel233.append('Associate Degree')
    elif educ['HIGH_EDU'] in {15}:
        educlevel233.append('Bachelor Degree')
    elif educ['HIGH_EDU'] in {16}:
        educlevel233.append('Master Degree')
    elif educ['HIGH_EDU'] in {17}:
        educlevel233.append('Professional/Doctorate Degree')
    else:
        educlevel233.append('N/A')
fmli233['Education level']=educlevel233

# %%
#educ_ref
#education for Q3
educlevel233ref=[]
for index, educ in fmli233.iterrows():
    if educ['EDUC_REF'] in {0,00,1,2,7,10,11}:
        educlevel233ref.append('No degree')
    elif educ['EDUC_REF'] in {3,4,12,13}:
        educlevel233ref.append('High School')
    elif educ['EDUC_REF'] in {14}:
        educlevel233ref.append('Associate Degree')
    elif educ['EDUC_REF'] in {5,6,15}:
        educlevel233ref.append('Bachelor Degree')
    elif educ['EDUC_REF'] in {16}:
        educlevel233ref.append('Master Degree')
    elif educ['EDUC_REF'] in {17}:
        educlevel233ref.append('Professional/Doctorate Degree')
    else:
        educlevel233ref.append('N/A')
fmli233['Education level 2']=educlevel233ref

# %%
#get rid of negative FINCBTAX Q3
#idk why thats there...
#fmli233=fmli233.loc[fmli233['FINCBTAX'] >= 0]

# %%
#Q3
#calc households income per capita
fmli233['Income per Capita']= fmli233['FINCBTAX']/fmli233['FAM_SIZE']

# %%
#convert Income per Capita to dollar amount 
#fmli233['Income per Capita'] = fmli233['Income per Capita'].apply(lambda x: "${:,.2f}".format(x))

# %%
#order it with the cusom order
fmli233['Education level']=pd.Categorical(fmli233['Education level'], categories= custom_order, ordered=True)

# %%
#order it with the cusom order
fmli233['Education level 2']=pd.Categorical(fmli233['Education level'], categories= custom_order, ordered=True)

# %%
fmli233.head()
# Out:
#      NEWID  DIRACC DIRACC_  AGE_REF AGE_REF_  AGE2 AGE2_  AS_COMP1 AS_C_MP1  \
# 0  5201374     1.0       D       23        D   NaN     A         0        D
# 1  5201414     1.0       D       79        D  78.0     D         1        D
# 2  5201464     1.0       D       65        D   NaN     A         2        D
# 3  5201474     1.0       D       72        D   NaN     A         0        D
# 4  5201664     1.0       D       71        D  71.0     D         2        D
#
#    AS_COMP2  ... CHDTXPH  CHDTXPH_ NUM_VET  FFTAXOWE FSTAXOWE  FINATXEM  \
# 0         1  ...     NaN         A       0      1402      860   24534.8
# 1         2  ...     NaN         A       1         0        0   36257.0
# 2         1  ...     NaN         A       0     12192     4152   74146.0
# 3         1  ...     NaN         A       0         0        0   16547.0
# 4         2  ...     NaN         A       0     36779     8888  238018.0
#
#     Region  Education level Education level 2  Income per Capita
# 0    South  Bachelor Degree   Bachelor Degree       24000.000000
# 1    South      High School       High School       12085.666667
# 2  Midwest    Master Degree     Master Degree           0.000000
# 3     West      High School       High School       16547.000000
# 4    South    Master Degree     Master Degree       70921.250000
#
# [5 rows x 823 columns]

# %% [markdown]
# # FMLI234

# %%
fmli234=pd.read_csv(r'C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw23\fmli234.csv')

# %%
#region for Q4
region234=[]
for index, region in fmli234.iterrows():
    if region['REGION']== 1:
        region234.append('Northeast')
    elif region['REGION']== 2:
        region234.append('Midwest')
    elif region['REGION']== 3:
        region234.append('South')
    elif region['REGION']== 4:
        region234.append('West')
    else:
        region234.append('N/A')
fmli234['Region']=region234

# %%
#EDUC FOR Q4
educlevel234=[]
for index, educ in fmli234.iterrows():
    if educ['HIGH_EDU'] in {0,00,10,11}:
        educlevel234.append('No degree')
    elif educ['HIGH_EDU'] in {12,13}:
        educlevel234.append('High School')
    elif educ['HIGH_EDU'] in {14}:
        educlevel234.append('Associate Degree')
    elif educ['HIGH_EDU'] in {15}:
        educlevel234.append('Bachelor Degree')
    elif educ['HIGH_EDU'] in {16}:
        educlevel234.append('Master Degree')
    elif educ['HIGH_EDU'] in {17}:
        educlevel234.append('Professional/Doctorate Degree')
    else:
        educlevel234.append('N/A')
fmli234['Education level']=educlevel234

# %%
#educ_ref
#education for Q4
educlevel234ref=[]
for index, educ in fmli234.iterrows():
    if educ['EDUC_REF'] in {0,00,1,2,7,10,11}:
        educlevel234ref.append('No degree')
    elif educ['EDUC_REF'] in {3,4,12,13}:
        educlevel234ref.append('High School')
    elif educ['EDUC_REF'] in {14}:
        educlevel234ref.append('Associate Degree')
    elif educ['EDUC_REF'] in {5,6,15}:
        educlevel234ref.append('Bachelor Degree')
    elif educ['EDUC_REF'] in {16}:
        educlevel234ref.append('Master Degree')
    elif educ['EDUC_REF'] in {17}:
        educlevel234ref.append('Professional/Doctorate Degree')
    else:
        educlevel234ref.append('N/A')
fmli234['Education level 2']=educlevel234ref

# %%
#get rid of negative FINCBTAX Q3
#idk why thats there...
#fmli234=fmli234.loc[fmli234['FINCBTAX'] >= 0]

# %%
# Q4 calc income per capita
fmli234['Income per Capita']= fmli234['FINCBTAX']/fmli234['FAM_SIZE']

# %%
#convert Income per Capita to dollar amount 
#fmli234['Income per Capita'] = fmli234['Income per Capita'].apply(lambda x: "${:,.2f}".format(x))

# %%
#order it with the cusom order
fmli234['Education level']=pd.Categorical(fmli234['Education level'], categories= custom_order, ordered=True)

# %%
#order it with the cusom order
fmli234['Education level 2']=pd.Categorical(fmli234['Education level'], categories= custom_order, ordered=True)

# %%
fmli234.head()
# Out:
#      NEWID  DIRACC DIRACC_  AGE_REF AGE_REF_  AGE2 AGE2_  AS_COMP1 AS_C_MP1  \
# 0  5251754     1.0       D       39        D  39.0     D         2        D
# 1  5251764     1.0       D       34        D  34.0     D         1        D
# 2  5251784     1.0       D       65        D   NaN     A         0        D
# 3  5251854     1.0       D       49        D   NaN     A         0        D
# 4  5251874     1.0       D       42        D   NaN     A         1        D
#
#    AS_COMP2  ... CHDTXPH  CHDTXPH_ NUM_VET  fftaxowe fstaxowe  FINATXEM  \
# 0         3  ...     NaN         A       1      2019        0   57981.0
# 1         1  ...     NaN         A       0     73297    27329  286715.6
# 2         1  ...     NaN         A       0         0        0   17197.0
# 3         2  ...     NaN         A       0      8815        0   74135.0
# 4         0  ...     NaN         A       0      6436     1969   55595.0
#
#     Region  Education level Education level 2  Income per Capita
# 0    South      High School       High School            12000.0
# 1  Midwest  Bachelor Degree   Bachelor Degree                0.0
# 2     West  Bachelor Degree   Bachelor Degree            16132.0
# 3     West  Bachelor Degree   Bachelor Degree            41475.0
# 4    South      High School       High School            64000.0
#
# [5 rows x 823 columns]

# %% [markdown]
# # Question 1: Do lower-income households have a lower level of education compared to high earning housholds?

# %% [markdown]
# # Q1

# %%
#keep relevant cols
educincome231=fmli231[['NEWID','Region','Education level','FINCBTAX', 'Income per Capita']]

# %%
educincome231.head()
# Out:
#      NEWID     Region  Education level  FINCBTAX  Income per Capita
# 0  5011064      South      High School      1979         659.666667
# 1  5011134  Northeast    Master Degree     48970       24485.000000
# 2  5011244    Midwest  Bachelor Degree    172600       86300.000000
# 3  5011314    Midwest      High School      7332        7332.000000
# 4  5011334       West      High School     43807       21903.500000

# %%
#clean up the data
#get rid of N/A vlaues from education
#get rid of N/A vlaues from region
    #group by region since income varies between region and it could offer more in depth insight
educincome231=educincome231.loc[(educincome231['Region'] != 'N/A')& (educincome231['Education level'] != 'N/A')]

# %%
#get rid of FINCBTAX values < 3 doesnt make sense 
educincome231= educincome231.loc[educincome231['FINCBTAX']>2]

# %%
educincome231avg=educincome231.groupby(['Region','Education level'])['Income per Capita'].mean()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\3317693998.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   educincome231avg=educincome231.groupby(['Region','Education level'])['Income per Capita'].mean()

# %%
educincome231avg = educincome231avg.reset_index()

# %%
#convert Income per Capita to dollar amount 
#educincome231avg['Income per Capita'] = educincome231avg['Income per Capita'].apply(lambda x: "{:,.2f}".format(x))

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=educincome231avg, x='Education level', y='Income per Capita', hue='Region', palette='viridis')#palette='mako')#palette='ocean')#palette='PuBuGn')
plt.title('2023 Q1 Average Income per Capita by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Income per Capita')
plt.legend(title='Region')
plt.show()

# %% [markdown]
# # Q2

# %%
#keep relevant cols
educincome232=fmli232[['NEWID','Region','Education level','FINCBTAX','Income per Capita']]

# %%
#clean up N/A from region and education level 
educincome232=educincome232.loc[(educincome232['Region'] != 'N/A')& (educincome232['Education level'] != 'N/A')]

# %%
#get rid of unrelastically low income
educincome232=educincome232.loc[educincome232['FINCBTAX']>5]

# %%
#avg houshold income per capita per region and educ level
educincome232avg=round(educincome232.groupby(['Region','Education level'])['Income per Capita'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\4034586373.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   educincome232avg=round(educincome232.groupby(['Region','Education level'])['Income per Capita'].mean(),2)

# %%
educincome232avg=educincome232avg.reset_index()
educincome232avg
# Out:
#        Region   Education level  Income per Capita
# 0     Midwest         No degree           18923.37
# 1     Midwest       High School           30562.66
# 2     Midwest  Associate Degree           38472.31
# 3     Midwest   Bachelor Degree           52270.93
# 4     Midwest     Master Degree           58552.85
# 5   Northeast         No degree           19796.67
# 6   Northeast       High School           33936.38
# 7   Northeast  Associate Degree           36688.90
# 8   Northeast   Bachelor Degree           63057.48
# 9   Northeast     Master Degree           84384.22
# 10      South         No degree           17638.02
# 11      South       High School           26762.52
# 12      South  Associate Degree           34819.99
# 13      South   Bachelor Degree           50306.35
# 14      South     Master Degree           70641.95
# 15       West         No degree           24568.10
# 16       West       High School           33128.93
# 17       West  Associate Degree           37308.63
# 18       West   Bachelor Degree           59978.82
# 19       West     Master Degree           72361.20

# %%
#make a visulizations....
plt.figure(figsize=(10, 6))
sns.barplot(data=educincome232avg, x='Education level', y='Income per Capita', hue='Region', palette='viridis')#palette='mako')#palette='ocean')#palette='PuBuGn')
plt.title('2023 Q2 Average Income per Capita by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Income per Capita')
plt.legend(title='Region')
plt.show()

# %% [markdown]
# # Q3

# %%
#keep relevant cols
educincome233=fmli233[['NEWID','Region','Education level','FINCBTAX','Income per Capita']]

# %%
#get rid of N/A vlaue from region and education levels
educincome233=educincome233.loc[(educincome233['Education level'] != 'N/A')&(educincome233['Region'] != 'N/A')]

# %%
#get rid of unrelastically low income
educincome233=educincome233.loc[educincome233['FINCBTAX']>2]

# %%
educincome233regionavg= educincome233.groupby(['Region','Education level'])['Income per Capita'].mean()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\2115042590.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   educincome233regionavg= educincome233.groupby(['Region','Education level'])['Income per Capita'].mean()

# %%
educincome233regionavg=educincome233regionavg.reset_index()
educincome233regionavg
# Out:
#        Region   Education level  Income per Capita
# 0     Midwest         No degree       17958.370145
# 1     Midwest       High School       32608.616894
# 2     Midwest  Associate Degree       37069.140942
# 3     Midwest   Bachelor Degree       49341.263115
# 4     Midwest     Master Degree       58343.033626
# 5   Northeast         No degree       19752.838384
# 6   Northeast       High School       28205.387261
# 7   Northeast  Associate Degree       39294.950000
# 8   Northeast   Bachelor Degree       60535.149457
# 9   Northeast     Master Degree       78353.283663
# 10      South         No degree       16428.021458
# 11      South       High School       26429.005797
# 12      South  Associate Degree       32249.199469
# 13      South   Bachelor Degree       46554.661644
# 14      South     Master Degree       67201.524852
# 15       West         No degree       16562.459877
# 16       West       High School       31601.598206
# 17       West  Associate Degree       34883.568397
# 18       West   Bachelor Degree       59195.001337
# 19       West     Master Degree       80169.755812

# %%
#make a visulizations....
plt.figure(figsize=(10, 6))
sns.barplot(data=educincome233regionavg, x='Education level', y='Income per Capita', hue='Region', palette='viridis')#palette='mako')#palette='ocean')#palette='PuBuGn')
plt.title('2023 Q3 Average Income per Capita by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Income per Capita')
plt.legend(title='Region')
plt.show()

# %% [markdown]
# # Q4

# %%
#keep relevant cols
educincome234= fmli234[['NEWID', 'Region', 'Education level', 'Income per Capita']]

# %%
#get rid of N/A vlaue from region and education levels
educincome234=educincome234.loc[(educincome234['Education level'] != 'N/A')&(educincome234['Region'] != 'N/A')]

# %%
#get rid of unrelastically low income
educincome233=educincome233.loc[educincome233['FINCBTAX']>1]

# %%
#avg icome per capita per region and education level
educincome234avg= round(educincome234.groupby(['Region','Education level'])['Income per Capita'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\3131840422.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   educincome234avg= round(educincome234.groupby(['Region','Education level'])['Income per Capita'].mean(),2)

# %%
educincome234avg=educincome234avg.reset_index()
educincome234avg
# Out:
#        Region   Education level  Income per Capita
# 0     Midwest         No degree           17820.96
# 1     Midwest       High School           30329.60
# 2     Midwest  Associate Degree           30906.92
# 3     Midwest   Bachelor Degree           49138.18
# 4     Midwest     Master Degree           59967.28
# 5   Northeast         No degree           15752.34
# 6   Northeast       High School           25992.87
# 7   Northeast  Associate Degree           32627.22
# 8   Northeast   Bachelor Degree           52128.44
# 9   Northeast     Master Degree           68843.70
# 10      South         No degree           18177.86
# 11      South       High School           23728.89
# 12      South  Associate Degree           29620.55
# 13      South   Bachelor Degree           45638.46
# 14      South     Master Degree           61033.53
# 15       West         No degree           17813.48
# 16       West       High School           31070.14
# 17       West  Associate Degree           36289.84
# 18       West   Bachelor Degree           57170.26
# 19       West     Master Degree           84806.29

# %%
#make a visulizations....
plt.figure(figsize=(10, 6))
sns.barplot(data=educincome234avg, x='Education level', y='Income per Capita', hue='Region', palette='viridis')#palette='mako')#palette='ocean')#palette='PuBuGn')
plt.title('2023 Q4 Average Income per Capita by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Income per Capita')
plt.legend(title='Region')
plt.show()

# %% [markdown]
# # Quarterly Avg Income per Capita by Education Level and Region

# %%
quarterlyeducinc=pd.concat([educincome231avg,educincome232avg,educincome233regionavg,educincome234avg])

# %%
quarterlyeducinc
# Out:
#      Region   Education level  Income per Capita
# 0   Midwest         No degree       19866.797078
# 1   Midwest       High School       28328.850697
# 2   Midwest  Associate Degree       37931.053547
# 3   Midwest   Bachelor Degree       50316.935251
# 4   Midwest     Master Degree       63088.217226
# ..      ...               ...                ...
# 15     West         No degree       17813.480000
# 16     West       High School       31070.140000
# 17     West  Associate Degree       36289.840000
# 18     West   Bachelor Degree       57170.260000
# 19     West     Master Degree       84806.290000
#
# [80 rows x 3 columns]

# %%
avgquarterlyeducinc=quarterlyeducinc.groupby(['Region','Education level'])['Income per Capita'].mean()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\1124024074.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avgquarterlyeducinc=quarterlyeducinc.groupby(['Region','Education level'])['Income per Capita'].mean()

# %%
avgquarterlyeducinc=avgquarterlyeducinc.reset_index()

# %%
avgquarterlyeducinc.to_csv('Avg_Income.csv',index=False)

# %%
import matplotlib.ticker as ticker
plt.figure(figsize=(10, 6))
sns.barplot(data=avgquarterlyeducinc, x='Education level', y='Income per Capita', hue='Region', palette='viridis')#palette='mako')#palette='ocean')#palette='PuBuGn')
plt.title('2023 Combined Quarterly Average Income per Capita by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Income per Capita')
plt.legend(title='Region', loc='upper left')
ax= plt.gca()
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('${x:,.0f}'))
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.5,alpha=0.3)
#plt.savefig('avgincome.png', transparent=True, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Question 2: Do households with higher education levels demonstrate more prudent spending patterns?
# a. Do higher educated households spend a lower percentage of their income on non-essentials compared to lower educated households?

# %% [markdown]
# Q1

# %%
#clean up: get rid of N/A region and Educ cols
fmli231spending=fmli231.loc[(fmli231['Region']!= 'N/A') & (fmli231['Education level'] != 'N/A')]

# %%
#read in MTBI
mtbi231=pd.read_csv(r"C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw22\mtbi231.csv")

# %%
#Categorize the UCC codes
nonessentials=[]
for index, nonessential in mtbi231.iterrows():
    if nonessential['UCC'] in {620212,620213,620215,620216,620222,620221,610900,620903,620926}:
        nonessentials.append('Entertainmnet and Recreation')
    elif nonessential['UCC'] in {430110,430120,640420}:
        nonessentials.append('Luxury Purchases')
    elif nonessential['UCC'] in {530110, 210210,530901, 680905,430130}:
        nonessentials.append('Vacation and Travel')
    elif nonessential['UCC'] in {450220,460902,520902,600132,600141,600110,600121,600122,600131,620919,620909,620907,620906,620921}:
        nonessentials.append('Vehicles and Watercrafts')
    elif nonessential['UCC'] in {620930,310350,310231,310243,310316,310314,310140,310231,310243,310232,310333,310400,340902,620917}:
        nonessentials.append('Technology')
    elif nonessential['UCC'] in {790330,790410,200900}: #790410 for dining out in MTBI231
        nonessentials.append('Dining out and Alcoholic Beverages')
    elif nonessential['UCC'] in {290430,280220,320233,320903,320904,990920,320345}:
        nonessentials.append('Home Aesthetics')
    elif nonessential['UCC'] in {340310,620112,680904,620918}:
        nonessentials.append('Services')
    else:
        nonessentials.append('N/A')
mtbi231['Non-essential']=nonessentials

# %%
#Clean mtbi: exclude 2022 itmes (Ref does not equal 2022)
mtbi231=mtbi231.loc[mtbi231['REF_YR'] != 2022]

# %%
#Clean: get rid NA cost and UCC
mtbi231=mtbi231.loc[(mtbi231['UCC']!='N/A') & (mtbi231['COST']>0)]

# %%
#merge data 
spending231= pd.merge(fmli231spending, mtbi231, on='NEWID', how='inner')

# %%
#keep relevant columns from fmli and mtbi
spending231=spending231[['NEWID','Region','Education level','FINCBTAX','COST', 'UCC']]

# %%
#filter out where cost exceeds income 
spending231=spending231.loc[spending231['COST']< spending231['FINCBTAX']]

# %%
#percentage of income spent on non-essentials 
spending231['Non-Essential Spending (%)'] = spending231['COST'] / spending231['FINCBTAX']*100

# %%
#avg percentage of income spent on non-essentials per region and education
#Region: to account for price differences between regions
percspending231avg=round(spending231.groupby(['Region', 'Education level'])['Non-Essential Spending (%)'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\586886721.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percspending231avg=round(spending231.groupby(['Region', 'Education level'])['Non-Essential Spending (%)'].mean(),2)

# %%
percspending231avg=percspending231avg.reset_index()
percspending231avg
# Out:
#        Region   Education level  Non-Essential Spending (%)
# 0     Midwest         No degree                        2.99
# 1     Midwest       High School                        1.90
# 2     Midwest  Associate Degree                        1.15
# 3     Midwest   Bachelor Degree                        1.09
# 4     Midwest     Master Degree                        1.15
# 5   Northeast         No degree                        1.97
# 6   Northeast       High School                        1.97
# 7   Northeast  Associate Degree                        1.26
# 8   Northeast   Bachelor Degree                        1.41
# 9   Northeast     Master Degree                        1.44
# 10      South         No degree                        2.61
# 11      South       High School                        2.54
# 12      South  Associate Degree                        1.66
# 13      South   Bachelor Degree                        1.63
# 14      South     Master Degree                        1.52
# 15       West         No degree                        3.04
# 16       West       High School                        1.67
# 17       West  Associate Degree                        1.34
# 18       West   Bachelor Degree                        1.39
# 19       West     Master Degree                        1.29

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percspending231avg, x='Education level', y='Non-Essential Spending (%)', hue='Region', palette= 'viridis' )
plt.title('2023 Q1 Average Percentage of Non-Essential Spending by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Non-Essential Spending (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q2

# %%
#clean up: get rid of N/A region and Educ cols
fmli232spending=fmli232.loc[(fmli232['Region']!= 'N/A') & (fmli232['Education level'] != 'N/A')]

# %%
mtbi232=pd.read_csv(r"C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw23\mtbi232.csv")

# %%
#Categorize the UCC codes
nonessentials=[]
for index, nonessential in mtbi232.iterrows():
    if nonessential['UCC'] in {620212,620213,620215,620216,620222,620221,610900,620903,620926}:
        nonessentials.append('Entertainmnet and Recreation')
    elif nonessential['UCC'] in {430110,430120,640420}:
        nonessentials.append('Luxury Purchases')
    elif nonessential['UCC'] in {530110, 210210,530901, 680905,430130}:
        nonessentials.append('Vacation and Travel')
    elif nonessential['UCC'] in {450220,460902,520902,600132,600141,600110,600121,600122,600131,620919,620909,620907,620906,620921}:
        nonessentials.append('Vehicles and Watercrafts')
    elif nonessential['UCC'] in {620930,310350,310231,310243,310316,310314,310140,310231,310243,310232,310333,310400,340902,620917}:
        nonessentials.append('Technology')
    elif nonessential['UCC'] in {790330,790400,200900}: #790400 for dining out in MTBI232
        nonessentials.append('Dining out and Alcoholic Beverages')
    elif nonessential['UCC'] in {290430,280220,320233,320903,320904,990920,320345}:
        nonessentials.append('Home Aesthetics')
    elif nonessential['UCC'] in {340310,620112,680904,620918}:
        nonessentials.append('Services')
    else:
        nonessentials.append('N/A')
mtbi232['Non-essential']=nonessentials

# %%
#clean get rid of NA/0 values form UCC and COST
mtbi232=mtbi232.loc[(mtbi232['UCC'] != 'N/A') & (mtbi232[ 'COST' ]>0)]

# %%
#merge data
spending232= pd.merge(fmli232spending, mtbi232, on= 'NEWID', how='inner')

# %%
##keep relevant columns from fmli and mtbi
spending232=spending232[['NEWID','Region','Education level','FINCBTAX','COST', 'UCC']]

# %%
#filter out where cost exceeds income
spending232=spending232.loc[spending232['COST' ]< spending232['FINCBTAX']]

# %%
#percentage of income per capita spent on non-essentials 
spending232['Non-Essential Spending (%)'] = spending232['COST' ] / spending232[ 'FINCBTAX' ]*100

# %%
#avg percentage of income spent on non-essentials per region and education
#Region: to account for price differences between regions
percspending232avg=round(spending232.groupby(['Region', 'Education level'])['Non-Essential Spending (%)'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\4068963185.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percspending232avg=round(spending232.groupby(['Region', 'Education level'])['Non-Essential Spending (%)'].mean(),2)

# %%
percspending232avg=percspending232avg.reset_index()
percspending232avg
# Out:
#        Region   Education level  Non-Essential Spending (%)
# 0     Midwest         No degree                        2.12
# 1     Midwest       High School                        1.80
# 2     Midwest  Associate Degree                        1.41
# 3     Midwest   Bachelor Degree                        1.39
# 4     Midwest     Master Degree                        1.20
# 5   Northeast         No degree                        1.90
# 6   Northeast       High School                        1.90
# 7   Northeast  Associate Degree                        1.48
# 8   Northeast   Bachelor Degree                        1.17
# 9   Northeast     Master Degree                        1.38
# 10      South         No degree                        2.71
# 11      South       High School                        2.55
# 12      South  Associate Degree                        1.84
# 13      South   Bachelor Degree                        1.76
# 14      South     Master Degree                        1.35
# 15       West         No degree                        2.29
# 16       West       High School                        1.79
# 17       West  Associate Degree                        1.65
# 18       West   Bachelor Degree                        1.58
# 19       West     Master Degree                        1.49

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percspending232avg, x='Education level', y='Non-Essential Spending (%)', hue='Region', palette= 'viridis')
plt.title('2023 Q2 Average Percentage of Non-Essential Spending by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Non-Essential Spending (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q3

# %%
#clean up: get rid of N/A region and Educ cols
fmli233spending=fmli233.loc[(fmli233['Region']!= 'N/A') & (fmli233['Education level'] != 'N/A')]

# %%
mtbi233= pd.read_csv(r"C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw23\mtbi233.csv")

# %%
#Categorize the UCC codes
nonessentials=[]
for index, nonessential in mtbi233.iterrows():
    if nonessential['UCC'] in {620212,620213,620215,620216,620222,620221,610900,620903,620926}:
        nonessentials.append('Entertainmnet and Recreation')
    elif nonessential['UCC'] in {430110,430120,640420}:
        nonessentials.append('Luxury Purchases')
    elif nonessential['UCC'] in {530110, 210210,530901, 680905,430130}:
        nonessentials.append('Vacation and Travel')
    elif nonessential['UCC'] in {450220,460902,520902,600132,600141,600110,600121,600122,600131,620919,620909,620907,620906,620921}:
        nonessentials.append('Vehicles and Watercrafts')
    elif nonessential['UCC'] in {620930,310350,310231,310243,310316,310314,310140,310231,310243,310232,310333,310400,340902,620917}:
        nonessentials.append('Technology')
    elif nonessential['UCC'] in {790330,790400,200900}: #790400 for dining out in MTBI233
        nonessentials.append('Dining out and Alcoholic Beverages')
    elif nonessential['UCC'] in {290430,280220,320233,320903,320904,990920,320345}:
        nonessentials.append('Home Aesthetics')
    elif nonessential['UCC'] in {340310,620112,680904,620918}:
        nonessentials.append('Services')
    else:
        nonessentials.append('N/A')
mtbi233['Non-essential']=nonessentials

# %%
#Clean: get rid NA cost and UCC
mtbi233=mtbi233.loc[(mtbi233['UCC'] != 'N/A') & (mtbi233[ 'COST' ]>0)]

# %%
#merge data
spending233= pd.merge(fmli233spending, mtbi233, on= 'NEWID', how='inner')

# %%
#keep relevant columns from fmli and mtbi
spending233=spending233[['NEWID','Region','Education level','FINCBTAX','COST', 'UCC']]

# %%
#filter out where cost exceeds income
spending233=spending233.loc[spending233['COST' ]< spending233['FINCBTAX']]

# %%
#percentage of income per capita spent on non-essentials 
spending233['Non-Essential Spending (%)'] = spending233['COST' ] / spending233[ 'FINCBTAX' ]*100

# %%
#avg percentage of income spent on non-essentials per region and education
#Region: to account for price differences between regions
percspending233avg=round(spending233.groupby(['Region', 'Education level'])['Non-Essential Spending (%)'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\2451613973.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percspending233avg=round(spending233.groupby(['Region', 'Education level'])['Non-Essential Spending (%)'].mean(),2)

# %%
percspending233avg=percspending233avg.reset_index()
percspending233avg
# Out:
#        Region   Education level  Non-Essential Spending (%)
# 0     Midwest         No degree                        2.52
# 1     Midwest       High School                        1.87
# 2     Midwest  Associate Degree                        1.48
# 3     Midwest   Bachelor Degree                        1.50
# 4     Midwest     Master Degree                        1.23
# 5   Northeast         No degree                        2.42
# 6   Northeast       High School                        1.87
# 7   Northeast  Associate Degree                        1.61
# 8   Northeast   Bachelor Degree                        1.45
# 9   Northeast     Master Degree                        1.50
# 10      South         No degree                        2.96
# 11      South       High School                        2.39
# 12      South  Associate Degree                        2.17
# 13      South   Bachelor Degree                        1.62
# 14      South     Master Degree                        1.35
# 15       West         No degree                        2.41
# 16       West       High School                        1.78
# 17       West  Associate Degree                        1.50
# 18       West   Bachelor Degree                        1.69
# 19       West     Master Degree                        1.31

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percspending233avg, x='Education level', y='Non-Essential Spending (%)', hue='Region',palette= 'viridis')
plt.title('2023 Q3 Average Percentage of Non-Essential Spending by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Non-Essential Spending (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q4

# %%
#clean up: get rid of N/A region and Educ cols
fmli234spending=fmli234.loc[(fmli234['Region']!= 'N/A') & (fmli234['Education level'] != 'N/A')]

# %%
mtbi234= pd.read_csv(r"C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw23\mtbi234.csv")

# %%
#Categorize the UCC codes
nonessentials=[]
for index, nonessential in mtbi234.iterrows():
    if nonessential['UCC'] in {620212,620213,620215,620216,620222,620221,610900,620903,620926}:
        nonessentials.append('Entertainmnet and Recreation')
    elif nonessential['UCC'] in {430110,430120,640420}:
        nonessentials.append('Luxury Purchases')
    elif nonessential['UCC'] in {530110, 210210,530901, 680905,430130}:
        nonessentials.append('Vacation and Travel')
    elif nonessential['UCC'] in {450220,460902,520902,600132,600141,600110,600121,600122,600131,620919,620909,620907,620906,620921}:
        nonessentials.append('Vehicles and Watercrafts')
    elif nonessential['UCC'] in {620930,310350,310231,310243,310316,310314,310140,310231,310243,310232,310333,310400,340902,620917}:
        nonessentials.append('Technology')
    elif nonessential['UCC'] in {790330,790400,200900}: #790400 for dining out in MTBI234
        nonessentials.append('Dining out and Alcoholic Beverages')
    elif nonessential['UCC'] in {290430,280220,320233,320903,320904,990920,320345}:
        nonessentials.append('Home Aesthetics')
    elif nonessential['UCC'] in {340310,620112,680904,620918}:
        nonessentials.append('Services')
    else:
        nonessentials.append('N/A')
mtbi234['Non-essential']=nonessentials

# %%
#Clean: get rid NA/0 cost and UCC
mtbi234=mtbi234.loc[(mtbi234['UCC'] != 'N/A') & (mtbi234[ 'COST' ]>0)]

# %%
#merge data
spending234= pd.merge(fmli234spending, mtbi234, on= 'NEWID', how='inner')

# %%
#keep relevant columns from fmli and mtbi
spending234=spending234[['NEWID','Region','Education level','FINCBTAX','COST', 'UCC']]

# %%
#filter out where cost exceeds income
spending234=spending234.loc[spending234['COST']< spending234['FINCBTAX']]

# %%
#percentage of income per capita spent on non-essentials 
spending234['Non-Essential Spending (%)'] = spending234['COST' ] / spending234[ 'FINCBTAX' ]*100

# %%
#avg percentage of income spent on non-essentials per region and education
#Region: to account for price differences between regions
percspending234avg=round(spending234.groupby(['Region', 'Education level'])['Non-Essential Spending (%)'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\2822825489.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percspending234avg=round(spending234.groupby(['Region', 'Education level'])['Non-Essential Spending (%)'].mean(),2)

# %%
percspending234avg=percspending234avg.reset_index()
percspending234avg
# Out:
#        Region   Education level  Non-Essential Spending (%)
# 0     Midwest         No degree                        3.45
# 1     Midwest       High School                        1.86
# 2     Midwest  Associate Degree                        1.37
# 3     Midwest   Bachelor Degree                        1.50
# 4     Midwest     Master Degree                        1.14
# 5   Northeast         No degree                        3.23
# 6   Northeast       High School                        1.98
# 7   Northeast  Associate Degree                        1.85
# 8   Northeast   Bachelor Degree                        1.46
# 9   Northeast     Master Degree                        1.41
# 10      South         No degree                        3.27
# 11      South       High School                        2.51
# 12      South  Associate Degree                        1.99
# 13      South   Bachelor Degree                        1.60
# 14      South     Master Degree                        1.50
# 15       West         No degree                        2.60
# 16       West       High School                        1.82
# 17       West  Associate Degree                        1.70
# 18       West   Bachelor Degree                        1.44
# 19       West     Master Degree                        1.29

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percspending234avg, x='Education level', y='Non-Essential Spending (%)', hue='Region',palette= 'viridis')
plt.title('2023 Q4 Average Percentage of Non-Essential Spending by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Non-Essential Spending (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Overall avg Quarterly expenditure

# %%
quarterlyspending=pd.concat([percspending231avg,percspending232avg,percspending233avg,percspending234avg])

# %%
quarterlyspending.head()
# Out:
#     Region   Education level  Non-Essential Spending (%)
# 0  Midwest         No degree                        2.99
# 1  Midwest       High School                        1.90
# 2  Midwest  Associate Degree                        1.15
# 3  Midwest   Bachelor Degree                        1.09
# 4  Midwest     Master Degree                        1.15

# %%
avgquarterlyspending=quarterlyspending.groupby(['Region','Education level'])['Non-Essential Spending (%)'].mean()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\88376198.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avgquarterlyspending=quarterlyspending.groupby(['Region','Education level'])['Non-Essential Spending (%)'].mean()

# %%
avgquarterlyspending=avgquarterlyspending.reset_index()

# %%
avgquarterlyspending
# Out:
#        Region   Education level  Non-Essential Spending (%)
# 0     Midwest         No degree                      2.7700
# 1     Midwest       High School                      1.8575
# 2     Midwest  Associate Degree                      1.3525
# 3     Midwest   Bachelor Degree                      1.3700
# 4     Midwest     Master Degree                      1.1800
# 5   Northeast         No degree                      2.3800
# 6   Northeast       High School                      1.9300
# 7   Northeast  Associate Degree                      1.5500
# 8   Northeast   Bachelor Degree                      1.3725
# 9   Northeast     Master Degree                      1.4325
# 10      South         No degree                      2.8875
# 11      South       High School                      2.4975
# 12      South  Associate Degree                      1.9150
# 13      South   Bachelor Degree                      1.6525
# 14      South     Master Degree                      1.4300
# 15       West         No degree                      2.5850
# 16       West       High School                      1.7650
# 17       West  Associate Degree                      1.5475
# 18       West   Bachelor Degree                      1.5250
# 19       West     Master Degree                      1.3450

# %%
avgquarterlyspending.to_csv('non_essential_spendingDF.csv',index=False)

# %%
plt.figure(figsize=(11, 7))
sns.barplot(data=avgquarterlyspending, x='Education level', y='Non-Essential Spending (%)', hue='Region',palette= 'viridis')
plt.title('2023 Combined Quarterly Average Percentage of Non-Essential Spending by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Non-Essential Spending')
plt.legend(title='Region')
plt.tight_layout()
ax= plt.gca()
ax.yaxis.set_major_formatter(ticker. StrMethodFormatter('{x:,.0f}%'))
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.5,alpha=0.3)
#plt.savefig('non-essentialspending.png', transparent=True)
plt.show()

# %% [markdown]
# # Question 3: Do households with higher education levels derive a greater proportion of their income from passive investment sources like interest and dividends compared to lower-educated households?

# %% [markdown]
# # Q1

# %%
#clean up data
investinc231= fmli231.loc[(fmli231['FINCBTAX'] > 0) &
                                (fmli231['Education level'] != 'N/A') &
                                (fmli231['Region'] != 'N/A')]

# %%
#keep relevant cols
investinc231 =investinc231[['NEWID','Region','Education level','INTRDVX','FINCBTAX']]

# %%
investinc231=investinc231.dropna(subset=['INTRDVX'])

# %%
investinc231=investinc231.loc[investinc231['INTRDVX']<investinc231['FINCBTAX']]

# %%
#calc the percetnage of income that comes from passive income
investinc231['Percentage of Passive Income']=investinc231['INTRDVX']/investinc231['FINCBTAX']*100

# %%
#avg percetnage of passive income per region and houshold
investinc231avg=round(investinc231.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\1372522486.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   investinc231avg=round(investinc231.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)

# %%
investinc231avg= investinc231avg.reset_index()
investinc231avg
# Out:
#        Region   Education level  Percentage of Passive Income
# 0     Midwest         No degree                          6.58
# 1     Midwest       High School                          3.89
# 2     Midwest  Associate Degree                          4.33
# 3     Midwest   Bachelor Degree                          5.73
# 4     Midwest     Master Degree                          2.69
# 5   Northeast         No degree                          0.09
# 6   Northeast       High School                          3.69
# 7   Northeast  Associate Degree                          5.35
# 8   Northeast   Bachelor Degree                          7.55
# 9   Northeast     Master Degree                          7.25
# 10      South         No degree                          8.16
# 11      South       High School                          4.30
# 12      South  Associate Degree                          2.48
# 13      South   Bachelor Degree                          2.89
# 14      South     Master Degree                         11.96
# 15       West         No degree                          0.00
# 16       West       High School                          7.81
# 17       West  Associate Degree                          3.68
# 18       West   Bachelor Degree                          5.71
# 19       West     Master Degree                          5.39

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=investinc231avg, x='Education level', y='Percentage of Passive Income', hue='Region', palette= 'viridis')
plt.title('2023 Q1 Average Percentage of Passive Income by Region and Education Level')
plt.xlabel('Education Level')
plt.ylabel('Average Percentage of Passive Income')
plt.legend(title='Education Level')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q2

# %%
#clean up data
investinc232= fmli232.loc[(fmli232['FINCBTAX'] > 0) &
                                (fmli232['Education level'] != 'N/A') &
                                (fmli232['Region'] != 'N/A')]

# %%
#keep relevant cols
investinc232 =investinc232[['NEWID','Region','Education level','INTRDVX','FINCBTAX']]

# %%
investinc232=investinc232.dropna(subset=['INTRDVX'])

# %%
investinc232=investinc232.loc[investinc232['INTRDVX' ]<investinc232['FINCBTAX']]

# %%
#calc the percetnage of income that comes from passive income
investinc232['Percentage of Passive Income']=investinc232['INTRDVX']/investinc232['FINCBTAX']*100

# %%
#avg percetnage of passive income per region and houshold
investinc232avg=round(investinc232.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\920217489.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   investinc232avg=round(investinc232.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)

# %%
investinc232avg=investinc232avg.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=investinc232avg, x='Education level', y='Percentage of Passive Income', hue='Region', palette= 'viridis')
plt.title('2023 Q2 Average Percentage of Passive Income by Region and Education Level')
plt.xlabel('Education Level')
plt.ylabel('Average Percentage of Passive Income')
plt.legend(title='Education Level')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q3

# %%
#clean up data
investinc233= fmli233.loc[(fmli233['FINCBTAX'] > 0) &
                                (fmli233['Education level'] != 'N/A') &
                                (fmli233['Region'] != 'N/A')]

# %%
investinc233=investinc233.dropna(subset=['INTRDVX'])

# %%
investinc233=investinc233.loc[investinc233['INTRDVX' ]<investinc233['FINCBTAX']]

# %%
#calc the percetnage of income that comes from passive income
investinc233['Percentage of Passive Income']=investinc233['INTRDVX']/investinc233['FINCBTAX']*100

# %%
#avg percetnage of passive income per region and houshold
investinc233avg=round(investinc233.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\831587484.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   investinc233avg=round(investinc233.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)

# %%
investinc233avg=investinc233avg.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=investinc233avg, x='Education level', y='Percentage of Passive Income', hue='Region', palette= 'viridis')
plt.title('2023 Q3 Average Percentage of Passive Income by Region and Education Level')
plt.xlabel('Education Level')
plt.ylabel('Average Percentage of Passive Income')
plt.legend(title='Education Level')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q4

# %%
#clean up data
investinc234= fmli234.loc[(fmli234['FINCBTAX'] > 0) &
                                (fmli234['Education level'] != 'N/A') &
                                (fmli234['Region'] != 'N/A')]

# %%
investinc234=investinc234.dropna(subset=['INTRDVX'])

# %%
investinc234=investinc234.loc[investinc234['INTRDVX' ]<investinc234['FINCBTAX']]

# %%
#calc the percetnage of income that comes from passive income
investinc234['Percentage of Passive Income']=investinc234['INTRDVX']/investinc234['FINCBTAX']*100

# %%
#avg percetnage of passive income per region and houshold
investinc234avg=round(investinc234.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\2708404195.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   investinc234avg=round(investinc234.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)

# %%
investinc234avg=investinc234avg.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=investinc234avg, x='Education level', y='Percentage of Passive Income', hue='Region', palette= 'viridis')
plt.title('2023 Q4 Average Percentage of Passive Income by Region and Education Level')
plt.xlabel('Education Level')
plt.ylabel('Average Percentage of Passive Income')
plt.legend(title='Education Level')
plt.tight_layout()
plt.show()

# %% [markdown]
# # overall percentage of passive income

# %%
quarterlyinvesting=pd.concat([investinc231avg,investinc232avg,investinc233avg,investinc234avg])

# %%
quarterlyinvesting.head()
# Out:
#     Region   Education level  Percentage of Passive Income
# 0  Midwest         No degree                          6.58
# 1  Midwest       High School                          3.89
# 2  Midwest  Associate Degree                          4.33
# 3  Midwest   Bachelor Degree                          5.73
# 4  Midwest     Master Degree                          2.69

# %%
avgquarterlyinvesting=quarterlyinvesting.groupby(['Region','Education level']) ['Percentage of Passive Income'].mean()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\2556076817.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avgquarterlyinvesting=quarterlyinvesting.groupby(['Region','Education level']) ['Percentage of Passive Income'].mean()

# %%
avgquarterlyinvesting= avgquarterlyinvesting.reset_index()

# %%
avgquarterlyinvesting
# Out:
#        Region   Education level  Percentage of Passive Income
# 0     Midwest         No degree                        2.9975
# 1     Midwest       High School                        5.8450
# 2     Midwest  Associate Degree                        4.1850
# 3     Midwest   Bachelor Degree                        8.7650
# 4     Midwest     Master Degree                        3.6700
# 5   Northeast         No degree                        6.1350
# 6   Northeast       High School                        2.1325
# 7   Northeast  Associate Degree                        4.2300
# 8   Northeast   Bachelor Degree                        6.8625
# 9   Northeast     Master Degree                        8.1700
# 10      South         No degree                        8.3500
# 11      South       High School                        3.6650
# 12      South  Associate Degree                        1.9850
# 13      South   Bachelor Degree                        4.3650
# 14      South     Master Degree                        9.0350
# 15       West         No degree                       12.8275
# 16       West       High School                        7.0825
# 17       West  Associate Degree                        7.0000
# 18       West   Bachelor Degree                        8.0200
# 19       West     Master Degree                        5.0650

# %%
avgquarterlyinvesting.to_csv('investing_DF.csv',index=False)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=avgquarterlyinvesting, x='Education level', y='Percentage of Passive Income', hue='Region', palette= 'viridis')
plt.title('2023 Combined Quarterly Average Percentage of Passive Income by Region and Education Level')
plt.xlabel('Education Level')
plt.ylabel('Average Passive Income ')
plt.legend(title='Education Level')
plt.tight_layout()
ax= plt.gca()
ax.yaxis.set_major_formatter(ticker. StrMethodFormatter('{x:,.0f}%'))
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.5,alpha=0.3)
#plt.savefig('Passive_Income.png', transparent=True)
plt.show()

# %% [markdown]
# # Question 4: Are households with higher education levels more likely to have retirement accounts compared to lower-educated households?
# a. Do you have any retirement accounts such as 401(k0s, IRAS, Thrift Saving Plans? (IRA)
# b. Do you have a defined retirement plan, such as a pension, from an employer? (DEFBENRP)

# %%
#USE EDUC_REF

# %% [markdown]
# # Part A: Q1

# %%
retire231=fmli231[['NEWID','Region','Education level 2','IRA']]

# %%
#drop na vlaues from IRA and DEFBENRP
retire231=retire231.dropna(subset=['IRA'])

# %%
#clean up data
retire231= retire231.loc[(retire231['Education level 2'] != 'N/A') &
                                (retire231['Region'] != 'N/A')]

# %%
#calculate the percentage of peple with retiremtn accounts per education level
#if ira = 1 = yes
#if ira = 2 = no
#not this does not account for differnt population levels within region and education levels
retire231perc=retire231.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['IRA'].count())*100
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\3575245693.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   retire231perc=retire231.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['IRA'].count())*100
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\3575245693.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   retire231perc=retire231.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['IRA'].count())*100

# %%
retire231perc=retire231perc.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=retire231perc.reset_index(), x='Education level 2', y=0, hue='Region',palette= 'viridis')  
plt.title('2023 Q1 Percentage of Households with Retirement Accounts by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Percentage of Households with Retirement Accounts (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q2 Part A

# %%
retire232=fmli232[['NEWID','Region','Education level 2','IRA','DEFBENRP']]

# %%
#drop na vlaues from IRA and DEFBENRP
retire232=retire232.dropna(subset=['IRA'])

# %%
#clean up data
retire232= retire232.loc[(retire232['Education level 2'] != 'N/A') &
                                (retire232['Region'] != 'N/A')]

# %%
#calculate the percentage of peple with retiremtn accounts per education level
#if ira = 1 = yes
#if ira = 2 = no
#note this does not account for diffent population levels with region and education level
percretireacc232=retire232.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['IRA'].count())*100
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\4109005613.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percretireacc232=retire232.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['IRA'].count())*100
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\4109005613.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   percretireacc232=retire232.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['IRA'].count())*100

# %%
percretireacc232=percretireacc232.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percretireacc232.reset_index(), x='Education level 2', y=0, hue='Region',palette= 'viridis')  
plt.title('2023 Q2 Percentage of Households with Retirement Accounts by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Percentage of Households with Retirement Accounts (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Part A: Q3

# %%
retire233=fmli233[['NEWID','Region','Education level 2','IRA','DEFBENRP']]

# %%
#drop na vlaues from IRA and DEFBENRP
retire233=retire233.dropna(subset=['IRA'])

# %%
#clean up data
retire233= retire233.loc[(retire233['Education level 2'] != 'N/A') &
                                (retire233['Region'] != 'N/A')]

# %%
#calculate the percentage of peple with retiremtn accounts per education level
#if ira = 1 = yes
#if ira = 2 = no
percretire233=round(retire233.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['DEFBENRP'].count()),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\2932445879.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percretire233=round(retire233.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['DEFBENRP'].count()),2)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\2932445879.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   percretire233=round(retire233.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['DEFBENRP'].count()),2)

# %%
percretire233=percretire233.reset_index()

# %%
percretire233.head()
# Out:
#     Region Education level 2     0
# 0  Midwest         No degree  0.21
# 1  Midwest       High School  0.45
# 2  Midwest  Associate Degree  0.65
# 3  Midwest   Bachelor Degree  0.66
# 4  Midwest     Master Degree  0.83

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percretire233.reset_index(), x='Education level 2', y=0, hue='Region',palette= 'viridis')  
plt.title('2023 Q3 Percentage of Households with Retirement Accounts by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Percentage of Households with Retirement Accounts (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Part A: Q4

# %%
retire234=fmli234[['NEWID','Region','Education level 2','IRA','DEFBENRP']]

# %%
#drop na vlaues from IRA and DEFBENRP
retire234=retire234.dropna(subset=['IRA'])

# %%
#clean up data
retire234= retire234.loc[(retire234['Education level 2'] != 'N/A') &
                                (retire234['Region'] != 'N/A')]

# %%
#calculate the percentage of peple with retiremtn accounts per education level and region
#if ira = 1 = yes
#if ira = 2 = no
percretire234=round(retire234.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['DEFBENRP'].count())*100,2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\445859945.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percretire234=round(retire234.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['DEFBENRP'].count())*100,2)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\445859945.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   percretire234=round(retire234.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['DEFBENRP'].count())*100,2)

# %%
percretire234=percretire234.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percretire234, x='Education level 2', y=0, hue='Region',palette= 'viridis')  
plt.title('2023 Q4 Percentage of Households with Retirement Accounts by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Percentage of Households with Retirement Accounts (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# visualizations
qaurterlyretirperc=pd.concat([retire231perc,percretireacc232,percretire233,percretire234])

# %%
qaurterlyretirperc.columns
# Out:
# Index(['Region', 'Education level 2', 0], dtype='object')

# %%
avgqaurterlyretirperc=qaurterlyretirperc.groupby(['Region' ,'Education level 2' ]) [ 0].mean()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_26172\3332525154.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avgqaurterlyretirperc=qaurterlyretirperc.groupby(['Region' ,'Education level 2' ]) [ 0].mean()

# %%
avgqaurterlyretirperc=avgqaurterlyretirperc.reset_index()

# %%
avgqaurterlyretirperc
# Out:
#        Region Education level 2          0
# 0     Midwest         No degree   8.576061
# 1     Midwest       High School  35.023553
# 2     Midwest  Associate Degree  47.445049
# 3     Midwest   Bachelor Degree  57.270844
# 4     Midwest     Master Degree  60.898816
# 5   Northeast         No degree  11.574622
# 6   Northeast       High School  33.648595
# 7   Northeast  Associate Degree  44.867222
# 8   Northeast   Bachelor Degree  53.167151
# 9   Northeast     Master Degree  57.511944
# 10      South         No degree   6.374814
# 11      South       High School  20.613634
# 12      South  Associate Degree  23.931389
# 13      South   Bachelor Degree  39.351517
# 14      South     Master Degree  51.630865
# 15       West         No degree   9.687500
# 16       West       High School  28.098007
# 17       West  Associate Degree  41.157299
# 18       West   Bachelor Degree  57.047711
# 19       West     Master Degree  60.065962

# %%
avgqaurterlyretirperc.to_csv('retire_DF.csv',index=False)

# %%
plt.figure(figsize=(11, 6))
sns.barplot(data=avgqaurterlyretirperc, x='Education level 2', y=0, hue='Region',palette= 'viridis')  
plt.title('2023 Combined Quarterly Average Percentage of Households with Retirement Accounts by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Percentage of Households with Retirement Accounts')
plt.legend(title='Region')
plt.tight_layout()
ax= plt.gca()
ax.yaxis.set_major_formatter(ticker. StrMethodFormatter('{x:,.0f}%'))
plt.grid(color = 'grey', linestyle = '--', linewidth = 0.5,alpha=0.3)
#plt.savefig('Retirement_Acc.png', transparent=True)
plt.show()

# %% [markdown]
# # Concat all df for Tableau

# %%
annualavg=pd.merge(avgquarterlyeducinc,avgquarterlyspending, on= ['Region','Education level'], how='outer')

# %%
annualavg
# Out:
#        Region   Education level  Income per Capita  Non-Essential Spending (%)
# 0     Midwest         No degree       18642.374306                      2.7700
# 1     Midwest       High School       30457.431898                      1.8575
# 2     Midwest  Associate Degree       36094.856122                      1.3525
# 3     Midwest   Bachelor Degree       50266.827092                      1.3700
# 4     Midwest     Master Degree       59987.845213                      1.1800
# 5   Northeast         No degree       19815.088222                      2.3800
# 6   Northeast       High School       30002.487592                      1.9300
# 7   Northeast  Associate Degree       37251.132331                      1.5500
# 8   Northeast   Bachelor Degree       60114.860639                      1.3725
# 9   Northeast     Master Degree       76019.541579                      1.4325
# 10      South         No degree       17457.805534                      2.8875
# 11      South       High School       25833.704923                      2.4975
# 12      South  Associate Degree       32641.270834                      1.9150
# 13      South   Bachelor Degree       48010.116254                      1.6525
# 14      South     Master Degree       66708.457230                      1.4300
# 15       West         No degree       18916.244571                      2.5850
# 16       West       High School       31587.123367                      1.7650
# 17       West  Associate Degree       35750.744515                      1.5475
# 18       West   Bachelor Degree       59080.103544                      1.5250
# 19       West     Master Degree       77485.573395                      1.3450

# %%
annualavg=pd.merge(annualavg, avgquarterlyinvesting, on= ['Region','Education level'], how='outer')

# %%
annualavg
# Out:
#        Region   Education level  Income per Capita  \
# 0     Midwest         No degree       18642.374306
# 1     Midwest       High School       30457.431898
# 2     Midwest  Associate Degree       36094.856122
# 3     Midwest   Bachelor Degree       50266.827092
# 4     Midwest     Master Degree       59987.845213
# 5   Northeast         No degree       19815.088222
# 6   Northeast       High School       30002.487592
# 7   Northeast  Associate Degree       37251.132331
# 8   Northeast   Bachelor Degree       60114.860639
# 9   Northeast     Master Degree       76019.541579
# 10      South         No degree       17457.805534
# 11      South       High School       25833.704923
# 12      South  Associate Degree       32641.270834
# 13      South   Bachelor Degree       48010.116254
# 14      South     Master Degree       66708.457230
# 15       West         No degree       18916.244571
# 16       West       High School       31587.123367
# 17       West  Associate Degree       35750.744515
# 18       West   Bachelor Degree       59080.103544
# 19       West     Master Degree       77485.573395
#
#     Non-Essential Spending (%)  Percentage of Passive Income
# 0                       2.7700                        2.9975
# 1                       1.8575                        5.8450
# 2                       1.3525                        4.1850
# 3                       1.3700                        8.7650
# 4                       1.1800                        3.6700
# 5                       2.3800                        6.1350
# 6                       1.9300                        2.1325
# 7                       1.5500                        4.2300
# 8                       1.3725                        6.8625
# 9                       1.4325                        8.1700
# 10                      2.8875                        8.3500
# 11                      2.4975                        3.6650
# 12                      1.9150                        1.9850
# 13                      1.6525                        4.3650
# 14                      1.4300                        9.0350
# 15                      2.5850                       12.8275
# 16                      1.7650                        7.0825
# 17                      1.5475                        7.0000
# 18                      1.5250                        8.0200
# 19                      1.3450                        5.0650

# %%
avgqaurterlyretirperc=avgqaurterlyretirperc.rename(columns={'Education level 2': 'Education level', 0: 'Percentage of Retirement Accounts'})

# %%
avgqaurterlyretirperc
# Out:
#        Region   Education level  Percentage of Retirement Accounts
# 0     Midwest         No degree                           8.576061
# 1     Midwest       High School                          35.023553
# 2     Midwest  Associate Degree                          47.445049
# 3     Midwest   Bachelor Degree                          57.270844
# 4     Midwest     Master Degree                          60.898816
# 5   Northeast         No degree                          11.574622
# 6   Northeast       High School                          33.648595
# 7   Northeast  Associate Degree                          44.867222
# 8   Northeast   Bachelor Degree                          53.167151
# 9   Northeast     Master Degree                          57.511944
# 10      South         No degree                           6.374814
# 11      South       High School                          20.613634
# 12      South  Associate Degree                          23.931389
# 13      South   Bachelor Degree                          39.351517
# 14      South     Master Degree                          51.630865
# 15       West         No degree                           9.687500
# 16       West       High School                          28.098007
# 17       West  Associate Degree                          41.157299
# 18       West   Bachelor Degree                          57.047711
# 19       West     Master Degree                          60.065962

# %%
annualavg=pd.merge(annualavg, avgqaurterlyretirperc, on= ['Region','Education level'], how='outer')

# %%
annualavg
# Out:
#        Region   Education level  Income per Capita  \
# 0     Midwest         No degree       18642.374306
# 1     Midwest       High School       30457.431898
# 2     Midwest  Associate Degree       36094.856122
# 3     Midwest   Bachelor Degree       50266.827092
# 4     Midwest     Master Degree       59987.845213
# 5   Northeast         No degree       19815.088222
# 6   Northeast       High School       30002.487592
# 7   Northeast  Associate Degree       37251.132331
# 8   Northeast   Bachelor Degree       60114.860639
# 9   Northeast     Master Degree       76019.541579
# 10      South         No degree       17457.805534
# 11      South       High School       25833.704923
# 12      South  Associate Degree       32641.270834
# 13      South   Bachelor Degree       48010.116254
# 14      South     Master Degree       66708.457230
# 15       West         No degree       18916.244571
# 16       West       High School       31587.123367
# 17       West  Associate Degree       35750.744515
# 18       West   Bachelor Degree       59080.103544
# 19       West     Master Degree       77485.573395
#
#     Non-Essential Spending (%)  Percentage of Passive Income  \
# 0                       2.7700                        2.9975
# 1                       1.8575                        5.8450
# 2                       1.3525                        4.1850
# 3                       1.3700                        8.7650
# 4                       1.1800                        3.6700
# 5                       2.3800                        6.1350
# 6                       1.9300                        2.1325
# 7                       1.5500                        4.2300
# 8                       1.3725                        6.8625
# 9                       1.4325                        8.1700
# 10                      2.8875                        8.3500
# 11                      2.4975                        3.6650
# 12                      1.9150                        1.9850
# 13                      1.6525                        4.3650
# 14                      1.4300                        9.0350
# 15                      2.5850                       12.8275
# 16                      1.7650                        7.0825
# 17                      1.5475                        7.0000
# 18                      1.5250                        8.0200
# 19                      1.3450                        5.0650
#
#     Percentage of Retirement Accounts
# 0                            8.576061
# 1                           35.023553
# 2                           47.445049
# 3                           57.270844
# 4                           60.898816
# 5                           11.574622
# 6                           33.648595
# 7                           44.867222
# 8                           53.167151
# 9                           57.511944
# 10                           6.374814
# 11                          20.613634
# 12                          23.931389
# 13                          39.351517
# 14                          51.630865
# 15                           9.687500
# 16                          28.098007
# 17                          41.157299
# 18                          57.047711
# 19                          60.065962

# %%
annualavg.to_csv('annualavg.csv',index=False)

# %% [markdown]
# # Are households with higher education levels less likely to have debt?
