# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # FMLI231

# %%
fmli231=pd.read_csv(r'C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw22\fmli231.csv')

# %%
#region for Q1
region231=[]
for index, region in fmli231.iterrows():
    if region['REGION']== 1:
        region231.append('Northeast')
    elif region['REGION']== 2:
        region231.append('Midwest')
    elif region['REGION']== 3:
        region231.append('South')
    elif region['REGION']== 4:
        region231.append('West')
    else:
        region231.append('N/A')
fmli231['Region']=region231

# %%
#education for Q1
educlevel231=[]
for index, educ in fmli231.iterrows():
    if educ['HIGH_EDU'] in {0,00,10,11}:
        educlevel231.append('No degree')
    elif educ['HIGH_EDU'] in {12,13}:
        educlevel231.append('High School')
    elif educ['HIGH_EDU'] in {14}:
        educlevel231.append('Associate Degree')
    elif educ['HIGH_EDU'] in {15}:
        educlevel231.append('Bachelor Degree')
    elif educ['HIGH_EDU'] in {16}:
        educlevel231.append('Master Degree')
    elif educ['HIGH_EDU'] in {17}:
        educlevel231.append('Professional/Doctorate Degree')
    else:
        educlevel231.append('N/A')
fmli231['Education level']=educlevel231

# %%
#educ_ref
#education for Q1
educlevel231ref=[]
for index, educ in fmli231.iterrows():
    if educ['EDUC_REF'] in {0,00,1,2,7,10,11}:
        educlevel231ref.append('No degree')
    elif educ['EDUC_REF'] in {3,4,12,13}:
        educlevel231ref.append('High School')
    elif educ['EDUC_REF'] in {14}:
        educlevel231ref.append('Associate Degree')
    elif educ['EDUC_REF'] in {5,6,15}:
        educlevel231ref.append('Bachelor Degree')
    elif educ['EDUC_REF'] in {16}:
        educlevel231ref.append('Master Degree')
    elif educ['EDUC_REF'] in {17}:
        educlevel231ref.append('Professional/Doctorate Degree')
    else:
        educlevel231ref.append('N/A')
fmli231['Education level 2']=educlevel231ref

# %%
# get rid of negative FINCBTAX Q1
#idk why thats there...
fmli231=fmli231.loc[fmli231['FINCBTAX'] >= 0]

# %%
#Q1
#how much income is available per person in the household
#FINCBTAX= Total amount of family income before taxes in the last 12 months (Collected data)
fmli231['Income per Capita']= fmli231['FINCBTAX']/fmli231['FAM_SIZE']

# %%
#convert FINCBTAX to dollar amount 
#fmli231['Income per Capita'] = fmli231['Income per Capita'].apply(lambda x: "${:,.2f}".format(x))

# %%
#educ order
custom_order=['No degree','High School','Associate Degree','Bachelor Degree', 'Master Degree']

# %%
#order it with the cusom order
fmli231['Education level']=pd.Categorical(fmli231['Education level'], categories= custom_order, ordered=True)

# %%
#order it with the cusom order
fmli231['Education level 2']=pd.Categorical(fmli231['Education level 2'], categories= custom_order, ordered=True)

# %%
fmli231.head()
# Out:
#      NEWID  DIRACC DIRACC_  AGE_REF AGE_REF_  AGE2 AGE2_  AS_COMP1 AS_C_MP1  \
# 0  5011064     1.0       D       87        T   NaN     A         1        D
# 1  5011134     1.0       D       73        D  75.0     D         1        D
# 2  5011244     1.0       D       47        D  44.0     D         1        D
# 3  5011314     1.0       D       82        D   NaN     A         0        D
# 4  5011334     1.0       D       87        T  80.0     D         1        D
#
#    AS_COMP2  ... CHDTXP_  CHDTXPH CHDTXPH_  FFTAXOWE FSTAXOWE  FINATXEM  \
# 0         2  ...       A      NaN        A     -4051      744   57240.2
# 1         1  ...       A      NaN        A     -6600        0   55570.0
# 2         1  ...       A      NaN        A     22325     4892  145383.0
# 3         1  ...       A      NaN        A     -1400        0    8732.0
# 4         1  ...       A      NaN        A     -6600     -148   50555.0
#
#       Region  Education level Education level 2  Income per Capita
# 0      South      High School       High School         659.666667
# 1  Northeast    Master Degree       High School       24485.000000
# 2    Midwest  Bachelor Degree   Bachelor Degree       86300.000000
# 3    Midwest      High School       High School        7332.000000
# 4       West      High School       High School       21903.500000
#
# [5 rows x 822 columns]

# %% [markdown]
# # FMLI232

# %%
fmli232=pd.read_csv(r'C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw23\fmli232.csv')

# %%
#region for Q2
region232=[]
for index, region in fmli232.iterrows():
    if region['REGION']== 1:
        region232.append('Northeast')
    elif region['REGION']== 2:
        region232.append('Midwest')
    elif region['REGION']== 3:
        region232.append('South')
    elif region['REGION']== 4:
        region232.append('West')
    else:
        region232.append('N/A')
fmli232['Region']=region232

# %%
#EDUC FOR Q2
educlevel232=[]
for index, educ in fmli232.iterrows():
    if educ['HIGH_EDU'] in {0,00,10,11}:
        educlevel232.append('No degree')
    elif educ['HIGH_EDU'] in {12,13}:
        educlevel232.append('High School')
    elif educ['HIGH_EDU'] in {14}:
        educlevel232.append('Associate Degree')
    elif educ['HIGH_EDU'] in {15}:
        educlevel232.append('Bachelor Degree')
    elif educ['HIGH_EDU'] in {16}:
        educlevel232.append('Master Degree')
    elif educ['HIGH_EDU'] in {17}:
        educlevel232.append('Professional/Doctorate Degree')
    else:
        educlevel232.append('N/A')
fmli232['Education level']=educlevel232

# %%
#educ_ref
#education for Q2
educlevel232ref=[]
for index, educ in fmli232.iterrows():
    if educ['EDUC_REF'] in {0,00,1,2,7,10,11}:
        educlevel232ref.append('No degree')
    elif educ['EDUC_REF'] in {3,4,12,13}:
        educlevel232ref.append('High School')
    elif educ['EDUC_REF'] in {14}:
        educlevel232ref.append('Associate Degree')
    elif educ['EDUC_REF'] in {5,6,15}:
        educlevel232ref.append('Bachelor Degree')
    elif educ['EDUC_REF'] in {16}:
        educlevel232ref.append('Master Degree')
    elif educ['EDUC_REF'] in {17}:
        educlevel232ref.append('Professional/Doctorate Degree')
    else:
        educlevel232ref.append('N/A')
fmli232['Education level 2']=educlevel232ref

# %%
#get rid of negative FINCBTAX Q2
#idk why thats there...
fmli232=fmli232.loc[fmli232['FINCBTAX'] >= 0]

# %%
#Q2 calc income per capita
fmli232['Income per Capita']= fmli232['FINCBTAX']/fmli232['FAM_SIZE']

# %%
#convert Income per Capita to dollar amount 
#fmli232['Income per Capita'] = fmli232['Income per Capita'].apply(lambda x: "${:,.2f}".format(x))

# %%
#order it with the cusom order
fmli232['Education level']=pd.Categorical(fmli232['Education level'], categories= custom_order, ordered=True)

# %%
#order it with the cusom order
fmli232['Education level 2']=pd.Categorical(fmli232['Education level'], categories= custom_order, ordered=True)

# %%
fmli232.head()
# Out:
#      NEWID  DIRACC DIRACC_  AGE_REF AGE_REF_  AGE2 AGE2_  AS_COMP1 AS_C_MP1  \
# 0  5090604     1.0       D       74        D  72.0     D         1        D
# 1  5090624     1.0       D       87        T   NaN     A         0        D
# 2  5090634     1.0       D       58        D   NaN     A         0        D
# 3  5090664     1.0       D       55        D  52.0     D         1        D
# 4  5090674     1.0       D       31        D  31.0     D         1        D
#
#    AS_COMP2  ... CHDTXPH  CHDTXPH_ NUM_VET  fftaxowe fstaxowe  FINATXEM  \
# 0         1  ...     NaN         A       1         0        0   40677.0
# 1         1  ...     NaN         A       0         0        0   13787.0
# 2         1  ...     NaN         A       0     20397     7544  107059.0
# 3         1  ...     NaN         A       0      3552     1489   57932.4
# 4         2  ...     NaN         A       0       415        0   36475.0
#
#   Region  Education level Education level 2  Income per Capita
# 0  South    Master Degree     Master Degree       20338.500000
# 1  South      High School       High School       13787.000000
# 2   West  Bachelor Degree   Bachelor Degree      135000.000000
# 3  South      High School       High School           0.000000
# 4   West      High School       High School       12473.333333
#
# [5 rows x 823 columns]

# %% [markdown]
# # FMLI233

# %%
fmli233=pd.read_csv(r'C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw23\fmli233.csv')

# %%
#region for Q3
region233=[]
for index, region in fmli233.iterrows():
    if region['REGION']== 1:
        region233.append('Northeast')
    elif region['REGION']== 2:
        region233.append('Midwest')
    elif region['REGION']== 3:
        region233.append('South')
    elif region['REGION']== 4:
        region233.append('West')
    else:
        region233.append('N/A')
fmli233['Region']=region233

# %%
#EDUC FOR Q3
educlevel233=[]
for index, educ in fmli233.iterrows():
    if educ['HIGH_EDU'] in {0,00,10,11}:
        educlevel233.append('No degree')
    elif educ['HIGH_EDU'] in {12,13}:
        educlevel233.append('High School')
    elif educ['HIGH_EDU'] in {14}:
        educlevel233.append('Associate Degree')
    elif educ['HIGH_EDU'] in {15}:
        educlevel233.append('Bachelor Degree')
    elif educ['HIGH_EDU'] in {16}:
        educlevel233.append('Master Degree')
    elif educ['HIGH_EDU'] in {17}:
        educlevel233.append('Professional/Doctorate Degree')
    else:
        educlevel233.append('N/A')
fmli233['Education level']=educlevel233

# %%
#educ_ref
#education for Q3
educlevel233ref=[]
for index, educ in fmli233.iterrows():
    if educ['EDUC_REF'] in {0,00,1,2,7,10,11}:
        educlevel233ref.append('No degree')
    elif educ['EDUC_REF'] in {3,4,12,13}:
        educlevel233ref.append('High School')
    elif educ['EDUC_REF'] in {14}:
        educlevel233ref.append('Associate Degree')
    elif educ['EDUC_REF'] in {5,6,15}:
        educlevel233ref.append('Bachelor Degree')
    elif educ['EDUC_REF'] in {16}:
        educlevel233ref.append('Master Degree')
    elif educ['EDUC_REF'] in {17}:
        educlevel233ref.append('Professional/Doctorate Degree')
    else:
        educlevel233ref.append('N/A')
fmli233['Education level 2']=educlevel233ref

# %%
#get rid of negative FINCBTAX Q3
#idk why thats there...
fmli233=fmli233.loc[fmli233['FINCBTAX'] >= 0]

# %%
#Q3
#calc households income per capita
fmli233['Income per Capita']= fmli233['FINCBTAX']/fmli233['FAM_SIZE']

# %%
#convert Income per Capita to dollar amount 
#fmli233['Income per Capita'] = fmli233['Income per Capita'].apply(lambda x: "${:,.2f}".format(x))

# %%
#order it with the cusom order
fmli233['Education level']=pd.Categorical(fmli233['Education level'], categories= custom_order, ordered=True)

# %%
#order it with the cusom order
fmli233['Education level 2']=pd.Categorical(fmli233['Education level'], categories= custom_order, ordered=True)

# %%
fmli233.head()
# Out:
#      NEWID  DIRACC DIRACC_  AGE_REF AGE_REF_  AGE2 AGE2_  AS_COMP1 AS_C_MP1  \
# 0  5201374     1.0       D       23        D   NaN     A         0        D
# 1  5201414     1.0       D       79        D  78.0     D         1        D
# 2  5201464     1.0       D       65        D   NaN     A         2        D
# 3  5201474     1.0       D       72        D   NaN     A         0        D
# 4  5201664     1.0       D       71        D  71.0     D         2        D
#
#    AS_COMP2  ... CHDTXPH  CHDTXPH_ NUM_VET  FFTAXOWE FSTAXOWE  FINATXEM  \
# 0         1  ...     NaN         A       0      1402      860   24534.8
# 1         2  ...     NaN         A       1         0        0   36257.0
# 2         1  ...     NaN         A       0     12192     4152   74146.0
# 3         1  ...     NaN         A       0         0        0   16547.0
# 4         2  ...     NaN         A       0     36779     8888  238018.0
#
#     Region  Education level Education level 2  Income per Capita
# 0    South  Bachelor Degree   Bachelor Degree       24000.000000
# 1    South      High School       High School       12085.666667
# 2  Midwest    Master Degree     Master Degree           0.000000
# 3     West      High School       High School       16547.000000
# 4    South    Master Degree     Master Degree       70921.250000
#
# [5 rows x 823 columns]

# %% [markdown]
# # FMLI234

# %%
fmli234=pd.read_csv(r'C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw23\fmli234.csv')

# %%
#region for Q4
region234=[]
for index, region in fmli234.iterrows():
    if region['REGION']== 1:
        region234.append('Northeast')
    elif region['REGION']== 2:
        region234.append('Midwest')
    elif region['REGION']== 3:
        region234.append('South')
    elif region['REGION']== 4:
        region234.append('West')
    else:
        region234.append('N/A')
fmli234['Region']=region234

# %%
#EDUC FOR Q4
educlevel234=[]
for index, educ in fmli234.iterrows():
    if educ['HIGH_EDU'] in {0,00,10,11}:
        educlevel234.append('No degree')
    elif educ['HIGH_EDU'] in {12,13}:
        educlevel234.append('High School')
    elif educ['HIGH_EDU'] in {14}:
        educlevel234.append('Associate Degree')
    elif educ['HIGH_EDU'] in {15}:
        educlevel234.append('Bachelor Degree')
    elif educ['HIGH_EDU'] in {16}:
        educlevel234.append('Master Degree')
    elif educ['HIGH_EDU'] in {17}:
        educlevel234.append('Professional/Doctorate Degree')
    else:
        educlevel234.append('N/A')
fmli234['Education level']=educlevel234

# %%
#educ_ref
#education for Q4
educlevel234ref=[]
for index, educ in fmli234.iterrows():
    if educ['EDUC_REF'] in {0,00,1,2,7,10,11}:
        educlevel234ref.append('No degree')
    elif educ['EDUC_REF'] in {3,4,12,13}:
        educlevel234ref.append('High School')
    elif educ['EDUC_REF'] in {14}:
        educlevel234ref.append('Associate Degree')
    elif educ['EDUC_REF'] in {5,6,15}:
        educlevel234ref.append('Bachelor Degree')
    elif educ['EDUC_REF'] in {16}:
        educlevel234ref.append('Master Degree')
    elif educ['EDUC_REF'] in {17}:
        educlevel234ref.append('Professional/Doctorate Degree')
    else:
        educlevel234ref.append('N/A')
fmli234['Education level 2']=educlevel234ref

# %%
#get rid of negative FINCBTAX Q3
#idk why thats there...
fmli234=fmli234.loc[fmli234['FINCBTAX'] >= 0]

# %%
# Q4 calc income per capita
fmli234['Income per Capita']= fmli234['FINCBTAX']/fmli234['FAM_SIZE']

# %%
#convert Income per Capita to dollar amount 
#fmli234['Income per Capita'] = fmli234['Income per Capita'].apply(lambda x: "${:,.2f}".format(x))

# %%
#order it with the cusom order
fmli234['Education level']=pd.Categorical(fmli234['Education level'], categories= custom_order, ordered=True)

# %%
#order it with the cusom order
fmli234['Education level 2']=pd.Categorical(fmli234['Education level'], categories= custom_order, ordered=True)

# %%
fmli234.head()
# Out:
#      NEWID  DIRACC DIRACC_  AGE_REF AGE_REF_  AGE2 AGE2_  AS_COMP1 AS_C_MP1  \
# 0  5251754     1.0       D       39        D  39.0     D         2        D
# 1  5251764     1.0       D       34        D  34.0     D         1        D
# 2  5251784     1.0       D       65        D   NaN     A         0        D
# 3  5251854     1.0       D       49        D   NaN     A         0        D
# 4  5251874     1.0       D       42        D   NaN     A         1        D
#
#    AS_COMP2  ... CHDTXPH  CHDTXPH_ NUM_VET  fftaxowe fstaxowe  FINATXEM  \
# 0         3  ...     NaN         A       1      2019        0   57981.0
# 1         1  ...     NaN         A       0     73297    27329  286715.6
# 2         1  ...     NaN         A       0         0        0   17197.0
# 3         2  ...     NaN         A       0      8815        0   74135.0
# 4         0  ...     NaN         A       0      6436     1969   55595.0
#
#     Region  Education level Education level 2  Income per Capita
# 0    South      High School       High School            12000.0
# 1  Midwest  Bachelor Degree   Bachelor Degree                0.0
# 2     West  Bachelor Degree   Bachelor Degree            16132.0
# 3     West  Bachelor Degree   Bachelor Degree            41475.0
# 4    South      High School       High School            64000.0
#
# [5 rows x 823 columns]

# %% [markdown]
# # Question 1: Do lower-income households have a lower level of education compared to high earning housholds?

# %% [markdown]
# # Q1

# %%
#keep relevant cols
educincome231=fmli231[['NEWID','Region','Education level','Income per Capita']]

# %%
educincome231.head()
# Out:
#      NEWID     Region  Education level  Income per Capita
# 0  5011064      South      High School         659.666667
# 1  5011134  Northeast    Master Degree       24485.000000
# 2  5011244    Midwest  Bachelor Degree       86300.000000
# 3  5011314    Midwest      High School        7332.000000
# 4  5011334       West      High School       21903.500000

# %%
#clean up the data
#get rid of N/A vlaues from education
#get rid of N/A vlaues from region
    #group by region since income varies between region and it could offer more in depth insight
educincome231=educincome231.loc[educincome231['Region'] != 'N/A']
educincome231=educincome231.loc[educincome231['Education level'] != 'N/A']

# %%
educincome231avg=educincome231.groupby(['Region','Education level'])['Income per Capita'].mean()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\3317693998.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   educincome231avg=educincome231.groupby(['Region','Education level'])['Income per Capita'].mean()

# %%
educincome231avg = educincome231avg.reset_index()

# %%
educincome231median=educincome231.groupby(['Region','Education level'])['Income per Capita'].median()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\2614626130.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   educincome231median=educincome231.groupby(['Region','Education level'])['Income per Capita'].median()

# %%
#convert Income per Capita to dollar amount 
#educincome231avg['Income per Capita'] = educincome231avg['Income per Capita'].apply(lambda x: "{:,.2f}".format(x))

# %%
#convert Income per Capita to dollar amount 
#educincome231median['Income per Capita'] = educincome231median['Income per Capita'].apply(lambda x: "${:,.2f}".format(x))

# %%
#educincome231median = educincome231median.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=educincome231avg, x='Education level', y='Income per Capita', hue='Region', palette='viridis')#palette='mako')#palette='ocean')#palette='PuBuGn')
plt.title('2023 Q1 Average Income per Capita by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Income per Capita')
plt.legend(title='Region')
plt.show()

# %% [markdown]
# # Q2

# %%
#keep relevant cols
educincome232=fmli232[['NEWID','Region','Education level','Income per Capita']]

# %%
#clean up N/A from region and education level 
educincome232=educincome232.loc[educincome232['Region'] != 'N/A' ]
educincome232=educincome232.loc[educincome232['Education level'] != 'N/A' ]

# %%
#avg houshold income per capita per region and educ level
educincome232avg=round(educincome232.groupby(['Region','Education level'])['Income per Capita'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\4034586373.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   educincome232avg=round(educincome232.groupby(['Region','Education level'])['Income per Capita'].mean(),2)

# %%
educincome232median=round(educincome232.groupby(['Region','Education level'])['Income per Capita'].median(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\3698810780.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   educincome232median=round(educincome232.groupby(['Region','Education level'])['Income per Capita'].median(),2)

# %%
educincome232avg
# Out:
# Region     Education level
# Midwest    No degree           17661.81
#            High School         28261.26
#            Associate Degree    35864.02
#            Bachelor Degree     50680.08
#            Master Degree       54713.32
# Northeast  No degree           19136.78
#            High School         32444.67
#            Associate Degree    34995.57
#            Bachelor Degree     58459.54
#            Master Degree       78148.93
# South      No degree           16294.17
#            High School         23798.18
#            Associate Degree    30688.81
#            Bachelor Degree     46313.80
#            Master Degree       65259.70
# West       No degree           21701.82
#            High School         30830.51
#            Associate Degree    34608.67
#            Bachelor Degree     56114.20
#            Master Degree       66927.94
# Name: Income per Capita, dtype: float64

# %%
educincome232median
# Out:
# Region     Education level
# Midwest    No degree           15000.00
#            High School         22062.50
#            Associate Degree    29925.00
#            Bachelor Degree     37000.50
#            Master Degree       47612.00
# Northeast  No degree           14981.00
#            High School         22250.00
#            Associate Degree    30150.00
#            Bachelor Degree     42889.50
#            Master Degree       58000.00
# South      No degree           13979.00
#            High School         17209.75
#            Associate Degree    24253.75
#            Bachelor Degree     34000.00
#            Master Degree       46105.60
# West       No degree           15406.50
#            High School         21708.33
#            Associate Degree    27263.67
#            Bachelor Degree     40770.00
#            Master Degree       50000.00
# Name: Income per Capita, dtype: float64

# %%
educincome232avg=educincome232avg.reset_index()
#make a visulizations....
plt.figure(figsize=(10, 6))
sns.barplot(data=educincome232avg, x='Education level', y='Income per Capita', hue='Region', palette='viridis')#palette='mako')#palette='ocean')#palette='PuBuGn')
plt.title('2023 Q2 Average Income per Capita by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Income per Capita')
plt.legend(title='Region')
plt.show()

# %% [markdown]
# # Q3

# %%
#keep relevant cols
educincome233=fmli233[['NEWID','Region','Education level','Income per Capita']]

# %%
#get rid of N/A vlaue from region and education levels
educincome233=educincome233[educincome233['Education level'] != 'N/A']
educincome233=educincome233[educincome233['Region'] != 'N/A']

# %%
educincome233regionavg= educincome233.groupby(['Region','Education level'])['Income per Capita'].mean()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\2115042590.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   educincome233regionavg= educincome233.groupby(['Region','Education level'])['Income per Capita'].mean()

# %%
educincome233regionmedian= educincome233.groupby(['Region','Education level'])['Income per Capita'].median()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\1643909058.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   educincome233regionmedian= educincome233.groupby(['Region','Education level'])['Income per Capita'].median()

# %%
educincome233regionavg
# Out:
# Region     Education level
# Midwest    No degree           17584.237434
#            High School         30656.005104
#            Associate Degree    34799.601701
#            Bachelor Degree     46963.370917
#            Master Degree       55425.884722
# Northeast  No degree           18106.768519
#            High School         26268.540926
#            Associate Degree    36800.032540
#            Bachelor Degree     55972.198492
#            Master Degree       72070.237332
# South      No degree           15535.194205
#            High School         23267.641467
#            Associate Degree    28767.751799
#            Bachelor Degree     42458.650641
#            Master Degree       61938.754834
# West       No degree           14425.368280
#            High School         29466.357336
#            Associate Degree    31198.684411
#            Bachelor Degree     55612.145993
#            Master Degree       75058.264669
# Name: Income per Capita, dtype: float64

# %%
educincome233regionmedian
# Out:
# Region     Education level
# Midwest    No degree           15787.500000
#            High School         23127.000000
#            Associate Degree    28877.250000
#            Bachelor Degree     37001.000000
#            Master Degree       45389.000000
# Northeast  No degree           13990.250000
#            High School         20000.000000
#            Associate Degree    28666.666667
#            Bachelor Degree     42333.333333
#            Master Degree       58384.250000
# South      No degree           14369.000000
#            High School         17855.000000
#            Associate Degree    24341.500000
#            Bachelor Degree     33256.166667
#            Master Degree       48200.000000
# West       No degree           11940.000000
#            High School         22340.500000
#            Associate Degree    26039.500000
#            Bachelor Degree     41397.500000
#            Master Degree       54876.666667
# Name: Income per Capita, dtype: float64

# %%
#plots....
educincome233regionavg=educincome233regionavg.reset_index()
#make a visulizations....
plt.figure(figsize=(10, 6))
sns.barplot(data=educincome233regionavg, x='Education level', y='Income per Capita', hue='Region', palette='viridis')#palette='mako')#palette='ocean')#palette='PuBuGn')
plt.title('2023 Q3 Average Income per Capita by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Income per Capita')
plt.legend(title='Region')
plt.show()

# %% [markdown]
# # Q4

# %%
#keep relevant cols
educincome234= fmli234[['NEWID', 'Region', 'Education level', 'Income per Capita']]

# %%
#clean up data
#remove N/A vlaues from educ and region
educincome234= educincome234.loc[educincome234['Region'] != 'N/A']
educincome234= educincome234.loc[educincome234['Education level'] != 'N/A']

# %%
#should ig et rid of these ????????????????
educincome234.loc[educincome234['Income per Capita'] == 0]
# Out:
#         NEWID     Region  Education level  Income per Capita
# 1     5251764    Midwest  Bachelor Degree                0.0
# 6     5251904      South      High School                0.0
# 11    5252104      South  Bachelor Degree                0.0
# 47    5253184      South  Bachelor Degree                0.0
# 59    5253564      South  Bachelor Degree                0.0
# ...       ...        ...              ...                ...
# 4573  5571091       West      High School                0.0
# 4580  5571291       West        No degree                0.0
# 4597  5571801       West    Master Degree                0.0
# 4628  5572621      South  Bachelor Degree                0.0
# 4650  5573141  Northeast      High School                0.0
#
# [339 rows x 4 columns]

# %%
#avg icome per capita per region and education level
educincome234avg= round(educincome234.groupby(['Region','Education level'])['Income per Capita'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\3131840422.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   educincome234avg= round(educincome234.groupby(['Region','Education level'])['Income per Capita'].mean(),2)

# %%
educincome234avg
# Out:
# Region     Education level
# Midwest    No degree           18203.17
#            High School         30329.60
#            Associate Degree    31254.20
#            Bachelor Degree     49138.18
#            Master Degree       59967.28
# Northeast  No degree           15752.34
#            High School         26120.02
#            Associate Degree    33191.91
#            Bachelor Degree     52128.44
#            Master Degree       68843.70
# South      No degree           18177.86
#            High School         23728.89
#            Associate Degree    29620.55
#            Bachelor Degree     45638.46
#            Master Degree       61033.53
# West       No degree           17813.48
#            High School         31070.14
#            Associate Degree    36289.84
#            Bachelor Degree     57170.26
#            Master Degree       84806.29
# Name: Income per Capita, dtype: float64

# %%
#median icome per capita per region and education level to account for varrying level of income per region and educ level
educincome234median= round(educincome234.groupby(['Region','Education level'])['Income per Capita'].median(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\2236595054.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   educincome234median= round(educincome234.groupby(['Region','Education level'])['Income per Capita'].median(),2)

# %%
educincome234median
# Out:
# Region     Education level
# Midwest    No degree           14672.17
#            High School         24879.00
#            Associate Degree    27500.00
#            Bachelor Degree     35000.00
#            Master Degree       50000.00
# Northeast  No degree           13834.50
#            High School         20242.00
#            Associate Degree    27007.17
#            Bachelor Degree     42111.00
#            Master Degree       51477.33
# South      No degree           13784.00
#            High School         17851.00
#            Associate Degree    24779.00
#            Bachelor Degree     33489.50
#            Master Degree       42792.62
# West       No degree           13759.50
#            High School         22412.00
#            Associate Degree    29183.95
#            Bachelor Degree     40689.50
#            Master Degree       58425.33
# Name: Income per Capita, dtype: float64

# %%
#visualizations........
#plots....
educincome234avg=educincome234avg.reset_index()
#make a visulizations....
plt.figure(figsize=(10, 6))
sns.barplot(data=educincome234avg, x='Education level', y='Income per Capita', hue='Region', palette='viridis')#palette='mako')#palette='ocean')#palette='PuBuGn')
plt.title('2023 Q4 Average Income per Capita by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Income per Capita')
plt.legend(title='Region')
plt.show()

# %% [markdown]
# # Question 2: Do households with higher education levels demonstrate more prudent spending patterns?
# a. Do higher educated households spend a lower percentage of their income on non-essentials compared to lower educated households?

# %% [markdown]
# Q1

# %%
#clean up: get rid of N/A region and Educ cols
fmli231spending=fmli231.loc[(fmli231['Region']!= 'N/A') & (fmli231['Education level'] != 'N/A')]

# %%
#read in MTBI
mtbi231=pd.read_csv(r"C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw22\mtbi231.csv")

# %%
#Categorize the UCC codes
nonessentials=[]
for index, nonessential in mtbi231.iterrows():
    if nonessential['UCC'] in {620212,620213,620215,620216,620222,620221,610900,620903,620926}:
        nonessentials.append('Entertainmnet and Recreation')
    elif nonessential['UCC'] in {430110,430120,640420}:
        nonessentials.append('Luxury Purchases')
    elif nonessential['UCC'] in {530110, 210210,530901, 680905,430130}:
        nonessentials.append('Vacation and Travel')
    elif nonessential['UCC'] in {450220,460902,520902,600132,600141,600110,600121,600122,600131,620919,620909,620907,620906,620921}:
        nonessentials.append('Vehicles and Watercrafts')
    elif nonessential['UCC'] in {620930,310350,310231,310243,310316,310314,310140,310231,310243,310232,310333,310400,340902,620917}:
        nonessentials.append('Technology')
    elif nonessential['UCC'] in {790330,790410,200900}: #790410 for dining out in MTBI231
        nonessentials.append('Dining out and Alcoholic Beverages')
    elif nonessential['UCC'] in {290430,280220,320233,320903,320904,990920,320345}:
        nonessentials.append('Home Aesthetics')
    elif nonessential['UCC'] in {340310,620112,680904,620918}:
        nonessentials.append('Services')
    else:
        nonessentials.append('N/A')
mtbi231['Non-essential']=nonessentials

# %%
#Clean mtbi: exclude 2022 itmes (Ref does not equal 2022)
mtbi231=mtbi231.loc[mtbi231['REF_YR'] != 2022]

# %%
#get rid of negative cost values
mtbi231 = mtbi231.loc[mtbi231['COST'] >= 0]

# %%
#merge data 
spending231= pd.merge(fmli231spending, mtbi231, on='NEWID', how='inner')

# %%
#keep relevant columns from fmli and mtbi
spending231=spending231[['NEWID','Region','Education level','FINCBTAX','Income per Capita','COST', 'UCC']]

# %%
#get rid of 0 vlaues in income per capita 
spending231=spending231.loc[spending231['FINCBTAX'] != 0]

# %%
#percentage of income spent on non-essentials 
spending231['Percentage of non-essential spending'] = spending231['COST'] / spending231['FINCBTAX']*100

# %%
#avg percentage of income spent on non-essentials per region and education
#Region: to account for price differences between regions
percspending231avg=round(spending231.groupby(['Region', 'Education level'])['Percentage of non-essential spending'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\81930843.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percspending231avg=round(spending231.groupby(['Region', 'Education level'])['Percentage of non-essential spending'].mean(),2)

# %%
percspending231avg=percspending231avg.reset_index()
percspending231avg
# Out:
#        Region   Education level  Percentage of non-essential spending
# 0     Midwest         No degree                                 11.99
# 1     Midwest       High School                                  6.52
# 2     Midwest  Associate Degree                                  1.37
# 3     Midwest   Bachelor Degree                                  1.36
# 4     Midwest     Master Degree                                  1.77
# 5   Northeast         No degree                                  4.61
# 6   Northeast       High School                                 13.92
# 7   Northeast  Associate Degree                                  1.60
# 8   Northeast   Bachelor Degree                                  2.48
# 9   Northeast     Master Degree                                  5.39
# 10      South         No degree                                 10.69
# 11      South       High School                                371.55
# 12      South  Associate Degree                                  2.89
# 13      South   Bachelor Degree                                  5.40
# 14      South     Master Degree                                 22.68
# 15       West         No degree                                 10.35
# 16       West       High School                                  4.59
# 17       West  Associate Degree                                  4.16
# 18       West   Bachelor Degree                                  3.39
# 19       West     Master Degree                                  2.79

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percspending231avg, x='Education level', y='Percentage of non-essential spending', hue='Region', palette= 'viridis' )
plt.title('2023 Q1 Average Percentage of Non-Essential Spending by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Non-Essential Spending (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#median to account for drastically diffring % of income spent on non-essentials
percspending231median=round(spending231.groupby(['Region', 'Education level'])['Percentage of non-essential spending'].median(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\970934286.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percspending231median=round(spending231.groupby(['Region', 'Education level'])['Percentage of non-essential spending'].median(),2)

# %%
percspending231median= percspending231median.reset_index()
percspending231median
# Out:
#        Region   Education level  Percentage of non-essential spending
# 0     Midwest         No degree                                  0.30
# 1     Midwest       High School                                  0.22
# 2     Midwest  Associate Degree                                  0.16
# 3     Midwest   Bachelor Degree                                  0.12
# 4     Midwest     Master Degree                                  0.10
# 5   Northeast         No degree                                  0.29
# 6   Northeast       High School                                  0.24
# 7   Northeast  Associate Degree                                  0.17
# 8   Northeast   Bachelor Degree                                  0.12
# 9   Northeast     Master Degree                                  0.10
# 10      South         No degree                                  0.45
# 11      South       High School                                  0.29
# 12      South  Associate Degree                                  0.18
# 13      South   Bachelor Degree                                  0.14
# 14      South     Master Degree                                  0.11
# 15       West         No degree                                  0.49
# 16       West       High School                                  0.21
# 17       West  Associate Degree                                  0.15
# 18       West   Bachelor Degree                                  0.12
# 19       West     Master Degree                                  0.09

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percspending231median, x='Education level', y='Percentage of non-essential spending', hue='Region', palette= 'viridis' )
plt.title('2023 Q1 Median Percentage of Non-Essential Spending by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Median Non-Essential Spending (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Q2

# %%
#clean up: get rid of N/A region and Educ cols
fmli232spending=fmli232.loc[(fmli232['Region']!= 'N/A') & (fmli232['Education level'] != 'N/A')]

# %%
mtbi232=pd.read_csv(r"C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw23\mtbi232.csv")

# %%
#Categorize the UCC codes
nonessentials=[]
for index, nonessential in mtbi232.iterrows():
    if nonessential['UCC'] in {620212,620213,620215,620216,620222,620221,610900,620903,620926}:
        nonessentials.append('Entertainmnet and Recreation')
    elif nonessential['UCC'] in {430110,430120,640420}:
        nonessentials.append('Luxury Purchases')
    elif nonessential['UCC'] in {530110, 210210,530901, 680905,430130}:
        nonessentials.append('Vacation and Travel')
    elif nonessential['UCC'] in {450220,460902,520902,600132,600141,600110,600121,600122,600131,620919,620909,620907,620906,620921}:
        nonessentials.append('Vehicles and Watercrafts')
    elif nonessential['UCC'] in {620930,310350,310231,310243,310316,310314,310140,310231,310243,310232,310333,310400,340902,620917}:
        nonessentials.append('Technology')
    elif nonessential['UCC'] in {790330,790400,200900}: #790400 for dining out in MTBI232
        nonessentials.append('Dining out and Alcoholic Beverages')
    elif nonessential['UCC'] in {290430,280220,320233,320903,320904,990920,320345}:
        nonessentials.append('Home Aesthetics')
    elif nonessential['UCC'] in {340310,620112,680904,620918}:
        nonessentials.append('Services')
    else:
        nonessentials.append('N/A')
mtbi232['Non-essential']=nonessentials

# %%
#get rid of negative cost values
mtbi232 = mtbi232.loc[mtbi232['COST'] >= 0]

# %%
#merge data
spending232= pd.merge(fmli232spending, mtbi232, on= 'NEWID', how='inner')

# %%
##keep relevant columns from fmli and mtbi
spending232=spending232[['NEWID','Region','Education level','FINCBTAX','Income per Capita','COST', 'UCC']]

# %%
#get rid of 0's from FINCBTAX
#note: that this get rid of people who may derive their inocme from other sources
spending232=spending232.loc[spending232['FINCBTAX'] != 0]

# %%
#percentage of income per capita spent on non-essentials 
spending232['Percentage of Non-essential Spending'] = spending232['COST'] / spending232['FINCBTAX']*100

# %%
#avg percentage of income spent on non-essentials per region and education
#Region: to account for price differences between regions
percspending232avg=round(spending232.groupby(['Region', 'Education level'])['Percentage of Non-essential Spending'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\3321659198.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percspending232avg=round(spending232.groupby(['Region', 'Education level'])['Percentage of Non-essential Spending'].mean(),2)

# %%
percspending232avg=percspending232avg.reset_index()
percspending232avg
# Out:
#        Region   Education level  Percentage of Non-essential Spending
# 0     Midwest         No degree                                  3.00
# 1     Midwest       High School                                 37.23
# 2     Midwest  Associate Degree                                  2.38
# 3     Midwest   Bachelor Degree                                  2.35
# 4     Midwest     Master Degree                                  2.02
# 5   Northeast         No degree                                  6.23
# 6   Northeast       High School                                  4.85
# 7   Northeast  Associate Degree                                  3.18
# 8   Northeast   Bachelor Degree                                 44.16
# 9   Northeast     Master Degree                                 29.18
# 10      South         No degree                                 11.39
# 11      South       High School                                 22.64
# 12      South  Associate Degree                                  3.89
# 13      South   Bachelor Degree                                122.60
# 14      South     Master Degree                                 12.62
# 15       West         No degree                                  3.39
# 16       West       High School                                  4.28
# 17       West  Associate Degree                                  4.34
# 18       West   Bachelor Degree                                  4.81
# 19       West     Master Degree                                663.92

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percspending232avg, x='Education level', y='Percentage of Non-essential Spending', hue='Region', palette= 'viridis')
plt.title('2023 Q2 Average Percentage of Non-Essential Spending by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Non-Essential Spending (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#median percentage of income spent on non-essentials per region and education
#Region: to account for price differences between regions
percspending232median=round(spending232.groupby(['Region', 'Education level'])['Percentage of Non-essential Spending'].median(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\2882872805.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percspending232median=round(spending232.groupby(['Region', 'Education level'])['Percentage of Non-essential Spending'].median(),2)

# %%
percspending232median=percspending232median.reset_index()
percspending232median
# Out:
#        Region   Education level  Percentage of Non-essential Spending
# 0     Midwest         No degree                                  0.33
# 1     Midwest       High School                                  0.23
# 2     Midwest  Associate Degree                                  0.17
# 3     Midwest   Bachelor Degree                                  0.14
# 4     Midwest     Master Degree                                  0.10
# 5   Northeast         No degree                                  0.41
# 6   Northeast       High School                                  0.26
# 7   Northeast  Associate Degree                                  0.17
# 8   Northeast   Bachelor Degree                                  0.12
# 9   Northeast     Master Degree                                  0.10
# 10      South         No degree                                  0.49
# 11      South       High School                                  0.31
# 12      South  Associate Degree                                  0.21
# 13      South   Bachelor Degree                                  0.16
# 14      South     Master Degree                                  0.11
# 15       West         No degree                                  0.42
# 16       West       High School                                  0.23
# 17       West  Associate Degree                                  0.18
# 18       West   Bachelor Degree                                  0.13
# 19       West     Master Degree                                  0.11

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percspending232median, x='Education level', y='Percentage of Non-essential Spending', hue='Region',palette= 'viridis')
plt.title('2023 Q2 Median Percentage of Non-Essential Spending by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Median Non-Essential Spending (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Q3

# %%
#clean up: get rid of N/A region and Educ cols
fmli233spending=fmli233.loc[(fmli233['Region']!= 'N/A') & (fmli233['Education level'] != 'N/A')]

# %%
mtbi233= pd.read_csv(r"C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw23\mtbi233.csv")

# %%
#Categorize the UCC codes
nonessentials=[]
for index, nonessential in mtbi233.iterrows():
    if nonessential['UCC'] in {620212,620213,620215,620216,620222,620221,610900,620903,620926}:
        nonessentials.append('Entertainmnet and Recreation')
    elif nonessential['UCC'] in {430110,430120,640420}:
        nonessentials.append('Luxury Purchases')
    elif nonessential['UCC'] in {530110, 210210,530901, 680905,430130}:
        nonessentials.append('Vacation and Travel')
    elif nonessential['UCC'] in {450220,460902,520902,600132,600141,600110,600121,600122,600131,620919,620909,620907,620906,620921}:
        nonessentials.append('Vehicles and Watercrafts')
    elif nonessential['UCC'] in {620930,310350,310231,310243,310316,310314,310140,310231,310243,310232,310333,310400,340902,620917}:
        nonessentials.append('Technology')
    elif nonessential['UCC'] in {790330,790400,200900}: #790400 for dining out in MTBI233
        nonessentials.append('Dining out and Alcoholic Beverages')
    elif nonessential['UCC'] in {290430,280220,320233,320903,320904,990920,320345}:
        nonessentials.append('Home Aesthetics')
    elif nonessential['UCC'] in {340310,620112,680904,620918}:
        nonessentials.append('Services')
    else:
        nonessentials.append('N/A')
mtbi233['Non-essential']=nonessentials

# %%
#get rid of negative cost values
mtbi233 = mtbi233.loc[mtbi233['COST'] >= 0]

# %%
#merge data
spending233= pd.merge(fmli233spending, mtbi233, on= 'NEWID', how='inner')

# %%
#keep relevant columns from fmli and mtbi
spending233=spending233[['NEWID','Region','Education level','FINCBTAX','Income per Capita','COST', 'UCC']]

# %%
#get rid of 0's from income per capita
#note: that this get rid of people who may derive their inocme from other sources
spending233=spending233.loc[spending233['FINCBTAX'] != 0]

# %%
#percentage of income per capita spent on non-essentials 
spending233['Percentage of Non-essential Spending'] = spending233['COST'] / spending233['FINCBTAX']*100

# %%
#avg percentage of income spent on non-essentials per region and education
#Region: to account for price differences between regions
percspending233avg=round(spending233.groupby(['Region', 'Education level'])['Percentage of Non-essential Spending'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\4001541716.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percspending233avg=round(spending233.groupby(['Region', 'Education level'])['Percentage of Non-essential Spending'].mean(),2)

# %%
#median percentage of income spent on non-essentials per region and education
#Region: to account for price differences between regions
percspending233median=round(spending233.groupby(['Region', 'Education level'])['Percentage of Non-essential Spending'].median(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\1258805247.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percspending233median=round(spending233.groupby(['Region', 'Education level'])['Percentage of Non-essential Spending'].median(),2)

# %%
percspending233avg=percspending233avg.reset_index()
percspending233avg
# Out:
#        Region   Education level  Percentage of Non-essential Spending
# 0     Midwest         No degree                                  4.90
# 1     Midwest       High School                                  4.65
# 2     Midwest  Associate Degree                                  4.83
# 3     Midwest   Bachelor Degree                                  5.42
# 4     Midwest     Master Degree                                409.20
# 5   Northeast         No degree                                  4.40
# 6   Northeast       High School                                 97.50
# 7   Northeast  Associate Degree                                  2.32
# 8   Northeast   Bachelor Degree                                  3.20
# 9   Northeast     Master Degree                                  6.39
# 10      South         No degree                                  6.78
# 11      South       High School                                 13.61
# 12      South  Associate Degree                                  6.19
# 13      South   Bachelor Degree                                  6.25
# 14      South     Master Degree                                  3.52
# 15       West         No degree                                  4.42
# 16       West       High School                                552.25
# 17       West  Associate Degree                                  3.30
# 18       West   Bachelor Degree                                  7.02
# 19       West     Master Degree                                401.04

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percspending233avg, x='Education level', y='Percentage of Non-essential Spending', hue='Region',palette= 'viridis')
plt.title('2023 Q3 Average Percentage of Non-Essential Spending by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Non-Essential Spending (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
percspending233median=percspending233median.reset_index()
percspending233median
# Out:
#        Region   Education level  Percentage of Non-essential Spending
# 0     Midwest         No degree                                  0.32
# 1     Midwest       High School                                  0.22
# 2     Midwest  Associate Degree                                  0.17
# 3     Midwest   Bachelor Degree                                  0.14
# 4     Midwest     Master Degree                                  0.10
# 5   Northeast         No degree                                  0.41
# 6   Northeast       High School                                  0.26
# 7   Northeast  Associate Degree                                  0.17
# 8   Northeast   Bachelor Degree                                  0.12
# 9   Northeast     Master Degree                                  0.10
# 10      South         No degree                                  0.56
# 11      South       High School                                  0.30
# 12      South  Associate Degree                                  0.23
# 13      South   Bachelor Degree                                  0.16
# 14      South     Master Degree                                  0.11
# 15       West         No degree                                  0.50
# 16       West       High School                                  0.22
# 17       West  Associate Degree                                  0.18
# 18       West   Bachelor Degree                                  0.13
# 19       West     Master Degree                                  0.09

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percspending233median, x='Education level', y='Percentage of Non-essential Spending', hue='Region',palette= 'viridis')
plt.title('2023 Q3 Median Percentage of Non-Essential Spending by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Median Non-Essential Spending (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Q4

# %%
#clean up: get rid of N/A region and Educ cols
fmli234spending=fmli234.loc[(fmli234['Region']!= 'N/A') & (fmli234['Education level'] != 'N/A')]

# %%
mtbi234= pd.read_csv(r"C:\Users\Owner\Documents\NSS\Capstone\Educationproj\data\intrvw23\mtbi234.csv")

# %%
#Categorize the UCC codes
nonessentials=[]
for index, nonessential in mtbi234.iterrows():
    if nonessential['UCC'] in {620212,620213,620215,620216,620222,620221,610900,620903,620926}:
        nonessentials.append('Entertainmnet and Recreation')
    elif nonessential['UCC'] in {430110,430120,640420}:
        nonessentials.append('Luxury Purchases')
    elif nonessential['UCC'] in {530110, 210210,530901, 680905,430130}:
        nonessentials.append('Vacation and Travel')
    elif nonessential['UCC'] in {450220,460902,520902,600132,600141,600110,600121,600122,600131,620919,620909,620907,620906,620921}:
        nonessentials.append('Vehicles and Watercrafts')
    elif nonessential['UCC'] in {620930,310350,310231,310243,310316,310314,310140,310231,310243,310232,310333,310400,340902,620917}:
        nonessentials.append('Technology')
    elif nonessential['UCC'] in {790330,790400,200900}: #790400 for dining out in MTBI234
        nonessentials.append('Dining out and Alcoholic Beverages')
    elif nonessential['UCC'] in {290430,280220,320233,320903,320904,990920,320345}:
        nonessentials.append('Home Aesthetics')
    elif nonessential['UCC'] in {340310,620112,680904,620918}:
        nonessentials.append('Services')
    else:
        nonessentials.append('N/A')
mtbi234['Non-essential']=nonessentials

# %%
#get rid of negative cost values
mtbi234 = mtbi234.loc[mtbi234['COST'] >= 0]

# %%
#merge data
spending234= pd.merge(fmli234spending, mtbi234, on= 'NEWID', how='inner')

# %%
#keep relevant columns from fmli and mtbi
spending234=spending234[['NEWID','Region','Education level','FINCBTAX','Income per Capita','COST', 'UCC']]

# %%
#get rid of 0's from income per capita
#note: that this get rid of people who may derive their inocme from other sources
spending234=spending234.loc[spending234['FINCBTAX'] != 0]

# %%
#percentage of income per capita spent on non-essentials 
spending234['Percentage of Non-essential Spending'] = spending234['COST'] / spending234['FINCBTAX']*100

# %%
#avg percentage of income spent on non-essentials per region and education
#Region: to account for price differences between regions
percspending234avg=round(spending234.groupby(['Region', 'Education level'])['Percentage of Non-essential Spending'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\2509608399.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percspending234avg=round(spending234.groupby(['Region', 'Education level'])['Percentage of Non-essential Spending'].mean(),2)

# %%
#median percentage of income spent on non-essentials per region and education
#Region: to account for price differences between regions
percspending234median=round(spending234.groupby(['Region', 'Education level'])['Percentage of Non-essential Spending'].median(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\273391152.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percspending234median=round(spending234.groupby(['Region', 'Education level'])['Percentage of Non-essential Spending'].median(),2)

# %%
percspending234avg=percspending234avg.reset_index()
percspending234avg
# Out:
#        Region   Education level  Percentage of Non-essential Spending
# 0     Midwest         No degree                                  4.41
# 1     Midwest       High School                                  6.29
# 2     Midwest  Associate Degree                                  1.99
# 3     Midwest   Bachelor Degree                                  3.67
# 4     Midwest     Master Degree                                 19.05
# 5   Northeast         No degree                                  9.32
# 6   Northeast       High School                                100.93
# 7   Northeast  Associate Degree                                  3.76
# 8   Northeast   Bachelor Degree                                 11.28
# 9   Northeast     Master Degree                                  3.21
# 10      South         No degree                                  6.44
# 11      South       High School                                  7.08
# 12      South  Associate Degree                                  8.52
# 13      South   Bachelor Degree                                447.32
# 14      South     Master Degree                                 34.02
# 15       West         No degree                                  6.85
# 16       West       High School                                599.63
# 17       West  Associate Degree                                  3.08
# 18       West   Bachelor Degree                                  4.51
# 19       West     Master Degree                               1318.19

# %%
percspending234median=percspending234median.reset_index()

# %%
#visuals
plt.figure(figsize=(10, 6))
sns.barplot(data=percspending234avg, x='Education level', y='Percentage of Non-essential Spending', hue='Region',palette= 'viridis')
plt.title('2023 Q4 Average Percentage of Non-Essential Spending by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Average Non-Essential Spending (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#visuals
plt.figure(figsize=(10, 6))
sns.barplot(data=percspending234median, x='Education level', y='Percentage of Non-essential Spending', hue='Region',palette= 'viridis')
plt.title('2023 Q4 Median Percentage of Non-Essential Spending by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Median Non-Essential Spending (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 3: Do households with higher education levels derive a greater proportion of their income from passive investment sources like interest and dividends compared to lower-educated households?

# %% [markdown]
# # Q1

# %%
#clean up data
investinc231= fmli231.loc[(fmli231['FINCBTAX'] != 0) &
                                (fmli231['Education level'] != 'N/A') &
                                (fmli231['Region'] != 'N/A')]

# %%
#drop nan values
investinc231=investinc231.dropna(subset=['INTRDVX'])

# %%
#keep relevant cols
investinc231 =investinc231[['NEWID','Region','Education level','INTRDVX','FINCBTAX']]

# %%
#calc the percetnage of income that comes from passive income
investinc231['Percentage of Passive Income']=investinc231['INTRDVX']/investinc231['FINCBTAX']*100

# %%
#avg percetnage of passive income per region and houshold
investinc231avg=round(investinc231.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\1372522486.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   investinc231avg=round(investinc231.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)

# %%
#median to .. between varying percentages of passive income from income
investinc231median=round(investinc231.groupby(['Region','Education level'])['Percentage of Passive Income'].median(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\1823397064.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   investinc231median=round(investinc231.groupby(['Region','Education level'])['Percentage of Passive Income'].median(),2)

# %%
investinc231avg= investinc231avg.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=investinc231avg, x='Education level', y='Percentage of Passive Income', hue='Region', palette= 'viridis')
plt.title('2023 Q1 Average Percentage of Passive Income by Region and Education Level')
plt.xlabel('Education Level')
plt.ylabel('Average Percentage of Passive Income')
plt.legend(title='Education Level')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q2

# %%
#clean up data
investinc232= fmli232.loc[(fmli232['FINCBTAX'] != 0) &
                                (fmli232['Education level'] != 'N/A') &
                                (fmli232['Region'] != 'N/A')]

# %%
#drop nan values
investinc232=investinc232.dropna(subset=['INTRDVX'])

# %%
#keep relevant cols
investinc232 =investinc232[['NEWID','Region','Education level','INTRDVX','FINCBTAX']]

# %%
#calc the percetnage of income that comes from passive income
investinc232['Percentage of Passive Income']=investinc232['INTRDVX']/investinc232['FINCBTAX']*100

# %%
#avg percetnage of passive income per region and houshold
investinc232avg=round(investinc232.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\920217489.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   investinc232avg=round(investinc232.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)

# %%
#median to .. between varying percentages of passive income from income
investinc232median=round(investinc232.groupby(['Region','Education level'])['Percentage of Passive Income'].median(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\3959775688.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   investinc232median=round(investinc232.groupby(['Region','Education level'])['Percentage of Passive Income'].median(),2)

# %%
investinc232avg=investinc232avg.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=investinc232avg, x='Education level', y='Percentage of Passive Income', hue='Region', palette= 'viridis')
plt.title('2023 Q2 Average Percentage of Passive Income by Region and Education Level')
plt.xlabel('Education Level')
plt.ylabel('Average Percentage of Passive Income')
plt.legend(title='Education Level')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q3

# %%
#clean up data
investinc233= fmli233.loc[(fmli233['FINCBTAX'] != 0) &
                                (fmli233['Education level'] != 'N/A') &
                                (fmli233['Region'] != 'N/A')]

# %%
#drop nan values
investinc233=investinc233.dropna(subset=['INTRDVX'])

# %%
#calc the percetnage of income that comes from passive income
investinc233['Percentage of Passive Income']=investinc233['INTRDVX']/investinc233['FINCBTAX']*100

# %%
#avg percetnage of passive income per region and houshold
investinc233avg=round(investinc233.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\831587484.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   investinc233avg=round(investinc233.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)

# %%
investinc233avg=investinc233avg.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=investinc233avg, x='Education level', y='Percentage of Passive Income', hue='Region', palette= 'viridis')
plt.title('2023 Q3 Average Percentage of Passive Income by Region and Education Level')
plt.xlabel('Education Level')
plt.ylabel('Average Percentage of Passive Income')
plt.legend(title='Education Level')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q4

# %%
#clean up data
investinc234= fmli234.loc[(fmli234['FINCBTAX'] != 0) &
                                (fmli234['Education level'] != 'N/A') &
                                (fmli234['Region'] != 'N/A')]

# %%
#drop nan values
investinc234=investinc234.dropna(subset=['INTRDVX'])

# %%
#calc the percetnage of income that comes from passive income
investinc234['Percentage of Passive Income']=investinc234['INTRDVX']/investinc234['FINCBTAX']*100

# %%
#avg percetnage of passive income per region and houshold
investinc234avg=round(investinc234.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\2708404195.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   investinc234avg=round(investinc234.groupby(['Region','Education level'])['Percentage of Passive Income'].mean(),2)

# %%
investinc234avg=investinc234avg.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=investinc234avg, x='Education level', y='Percentage of Passive Income', hue='Region', palette= 'viridis')
plt.title('2023 Q4 Average Percentage of Passive Income by Region and Education Level')
plt.xlabel('Education Level')
plt.ylabel('Average Percentage of Passive Income')
plt.legend(title='Education Level')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 4: Are households with higher education levels more likely to have retirement accounts compared to lower-educated households?
# a. Do you have any retirement accounts such as 401(k0s, IRAS, Thrift Saving Plans? (IRA)
# b. Do you have a defined retirement plan, such as a pension, from an employer? (DEFBENRP)

# %%
#USE EDUC_REF

# %% [markdown]
# # Part A: Q1

# %%
retire231=fmli231[['NEWID','Region','Education level 2','IRA','DEFBENRP']]

# %%
#drop na vlaues from IRA and DEFBENRP
retire231a=retire231.dropna(subset=['IRA'])

# %%
#clean up data
retire231a= retire231a.loc[(retire231a['Education level 2'] != 'N/A') &
                                (retire231a['Region'] != 'N/A')]

# %%
#calculate the percentage of peple with retiremtn accounts per education level
#if ira = 1 = yes
#if ira = 2 = no
#not this does not account for differnt population levels within region and education levels
retireacc231perc=retire231a.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['IRA'].count())*100
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\3513106352.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   retireacc231perc=retire231a.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['IRA'].count())*100
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\3513106352.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   retireacc231perc=retire231a.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['IRA'].count())*100

# %%
retireacc231perc=retireacc231perc.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=retireacc231perc.reset_index(), x='Education level 2', y=0, hue='Region',palette= 'viridis')  
plt.title('2023 Q1 Percentage of Households with Retirement Accounts by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Percentage of Households with Retirement Accounts (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Part B: Q1

# %%
retire231b=retire231.dropna(subset=['DEFBENRP'])

# %%
#clean up data
retire231b= retire231b.loc[(retire231b['Education level 2'] != 'N/A') &
                                (retire231b['Region'] != 'N/A')]

# %%
#calculate the percentage of peple with retiremtn accounts per education level
#if DEFBENRP = 1 = yes
#if DEFBENRP = 2 = no
#not this does not account for differnt population levels within region and education levels
retire231b=retire231b.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['DEFBENRP'] == 1])['DEFBENRP'].count())/ x['DEFBENRP'].count())
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_11084\2495381893.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   retire231b=retire231b.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['DEFBENRP'] == 1])['DEFBENRP'].count())/ x['DEFBENRP'].count())
# C:\Users\Owner\AppData\Local\Temp\ipykernel_11084\2495381893.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   retire231b=retire231b.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['DEFBENRP'] == 1])['DEFBENRP'].count())/ x['DEFBENRP'].count())

# %%
retire231b
# Out:
# Region     Education level 2
# Midwest    No degree            0.000000
#            High School          0.378788
#            Associate Degree     0.368421
#            Bachelor Degree      0.279412
#            Master Degree        0.405405
# Northeast  No degree            0.125000
#            High School          0.200000
#            Associate Degree     0.370370
#            Bachelor Degree      0.333333
#            Master Degree        0.344828
# South      No degree            0.050000
#            High School          0.126984
#            Associate Degree     0.078947
#            Bachelor Degree      0.242718
#            Master Degree        0.298701
# West       No degree            0.100000
#            High School          0.130435
#            Associate Degree     0.205882
#            Bachelor Degree      0.252874
#            Master Degree        0.428571
# dtype: float64

# %% [markdown]
# # Q2 Part A

# %%
retire232=fmli232[['NEWID','Region','Education level 2','IRA','DEFBENRP']]

# %%
#drop na vlaues from IRA and DEFBENRP
retire232a=retire232.dropna(subset=['IRA'])

# %%
#clean up data
retire232a= retire232a.loc[(retire232a['Education level 2'] != 'N/A') &
                                (retire232a['Region'] != 'N/A')]

# %%
#calculate the percentage of peple with retiremtn accounts per education level
#if ira = 1 = yes
#if ira = 2 = no
#note this does not account for diffent population levels with region and education level
percretireacc232a=retire232a.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['IRA'].count())*100
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\1290011443.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percretireacc232a=retire232a.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['IRA'].count())*100
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\1290011443.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   percretireacc232a=retire232a.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['IRA'].count())*100

# %%
percretireacc232a=percretireacc232a.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percretireacc232a.reset_index(), x='Education level 2', y=0, hue='Region',palette= 'viridis')  
plt.title('2023 Q2 Percentage of Households with Retirement Accounts by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Percentage of Households with Retirement Accounts (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Part B: Q2

# %%
retire232b=retire232.dropna(subset=['DEFBENRP'])

# %%
#clean up data
retire232b= retire232b.loc[(retire232b['Education level 2'] != 'N/A') &
                                (retire232b['Region'] != 'N/A')]

# %%
#calculate the percentage of peple with retiremtn accounts per education level
#if DEFBENRP = 1 = yes
#if DEFBENRP = 2 = no
percretire232b=retire232b.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['DEFBENRP'] == 1])['DEFBENRP'].count())/ x['DEFBENRP'].count())
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_11084\3792147953.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   retire232b=retire232b.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['DEFBENRP'] == 1])['DEFBENRP'].count())/ x['DEFBENRP'].count())
# C:\Users\Owner\AppData\Local\Temp\ipykernel_11084\3792147953.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   retire232b=retire232b.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['DEFBENRP'] == 1])['DEFBENRP'].count())/ x['DEFBENRP'].count())

# %%
percretire232b
# Out:
# Region     Education level 2
# Midwest    No degree            0.000000
#            High School          0.250000
#            Associate Degree     0.363636
#            Bachelor Degree      0.367347
#            Master Degree        0.378378
# Northeast  No degree            0.000000
#            High School          0.275362
#            Associate Degree     0.166667
#            Bachelor Degree      0.266667
#            Master Degree        0.365385
# South      No degree            0.043478
#            High School          0.125874
#            Associate Degree     0.133333
#            Bachelor Degree      0.222222
#            Master Degree        0.238806
# West       No degree            0.000000
#            High School          0.194805
#            Associate Degree     0.277778
#            Bachelor Degree      0.301075
#            Master Degree        0.359375
# dtype: float64

# %% [markdown]
# # Part A: Q3

# %%
retire233=fmli233[['NEWID','Region','Education level 2','IRA','DEFBENRP']]

# %%
#drop na vlaues from IRA and DEFBENRP
retire233a=retire233.dropna(subset=['IRA'])

# %%
#clean up data
retire233a= retire233a.loc[(retire233a['Education level 2'] != 'N/A') &
                                (retire233a['Region'] != 'N/A')]

# %%
#calculate the percentage of peple with retiremtn accounts per education level
#if ira = 1 = yes
#if ira = 2 = no
percretire233a=round(retire233a.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['DEFBENRP'].count()),2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\2595484859.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percretire233a=round(retire233a.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['DEFBENRP'].count()),2)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\2595484859.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   percretire233a=round(retire233a.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['DEFBENRP'].count()),2)

# %%
percretire233a=percretire233a.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percretire233a.reset_index(), x='Education level 2', y=0, hue='Region',palette= 'viridis')  
plt.title('2023 Q3 Percentage of Households with Retirement Accounts by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Percentage of Households with Retirement Accounts (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Part B: Q3

# %%
retire233b=retire233.dropna(subset=['DEFBENRP'])

# %%
#clean up data
retire233b= retire233b.loc[(retire233b['Education level 2'] != 'N/A') &
                                (retire233b['Region'] != 'N/A')]

# %%
#calculate the percentage of peple with retiremtn accounts per education level
#if DEFBENRP = 1 = yes
#if DEFBENRP = 2 = no
percretire233=round(retire233b.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['DEFBENRP'] == 1])['DEFBENRP'].count())/ x['DEFBENRP'].count())*100,2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_11084\2504679477.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percretire233=round(retire233b.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['DEFBENRP'] == 1])['DEFBENRP'].count())/ x['DEFBENRP'].count())*100,2)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_11084\2504679477.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   percretire233=round(retire233b.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['DEFBENRP'] == 1])['DEFBENRP'].count())/ x['DEFBENRP'].count())*100,2)

# %%
percretire233
# Out:
# Region     Education level 2
# Midwest    No degree             0.00
#            High School          19.44
#            Associate Degree     34.78
#            Bachelor Degree      22.58
#            Master Degree        42.55
# Northeast  No degree             8.33
#            High School          18.75
#            Associate Degree     31.58
#            Bachelor Degree      19.51
#            Master Degree        39.66
# South      No degree             0.00
#            High School          14.46
#            Associate Degree     10.81
#            Bachelor Degree      19.81
#            Master Degree        17.11
# West       No degree            13.33
#            High School          22.86
#            Associate Degree     13.89
#            Bachelor Degree      26.97
#            Master Degree        19.40
# dtype: float64

# %% [markdown]
# # Part A: Q4

# %%
retire234a=fmli234[['NEWID','Region','Education level 2','IRA','DEFBENRP']]

# %%
#drop na vlaues from IRA and DEFBENRP
retire234a=retire234.dropna(subset=['IRA'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[444], line 2
#       1 #drop na vlaues from IRA and DEFBENRP
# ----> 2 retire234a=retire234.dropna(subset=['IRA'])
#
# NameError: name 'retire234' is not defined

# %%
#clean up data
retire234a= retire234a.loc[(retire234a['Education level 2'] != 'N/A') &
                                (retire234a['Region'] != 'N/A')]

# %%
#calculate the percentage of peple with retiremtn accounts per education level and region
#if ira = 1 = yes
#if ira = 2 = no
percretire234a=round(retire234a.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['DEFBENRP'].count())*100,2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\669815618.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percretire234a=round(retire234a.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['DEFBENRP'].count())*100,2)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_18540\669815618.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   percretire234a=round(retire234a.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['IRA'] == 1])['IRA'].count())/ x['DEFBENRP'].count())*100,2)

# %%
percretire234a=percretire234a.reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=percretire234a.reset_index(), x='Education level 2', y=0, hue='Region',palette= 'viridis')  
plt.title('2023 Q4 Percentage of Households with Retirement Accounts by Education Level and Region')
plt.xlabel('Education Level')
plt.ylabel('Percentage of Households with Retirement Accounts (%)')
plt.legend(title='Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Part B: Q4

# %%
retire234b=retire234.dropna(subset=['DEFBENRP'])

# %%
#clean up data
retire234b= retire234b.loc[(retire234b['Education level 2'] != 'N/A') &
                                (retire234b['Region'] != 'N/A')]

# %%
#calculate the percentage of peple with retiremtn accounts per education level
#if DEFBENRP = 1 = yes
#if DEFBENRP = 2 = no
percretire234=round(retire234b.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['DEFBENRP'] == 1])['DEFBENRP'].count())/ x['DEFBENRP'].count())*100,2)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_11084\1064980012.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percretire234=round(retire234b.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['DEFBENRP'] == 1])['DEFBENRP'].count())/ x['DEFBENRP'].count())*100,2)
# C:\Users\Owner\AppData\Local\Temp\ipykernel_11084\1064980012.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   percretire234=round(retire234b.groupby(['Region','Education level 2']).apply(lambda x: ((x.loc[x['DEFBENRP'] == 1])['DEFBENRP'].count())/ x['DEFBENRP'].count())*100,2)

# %%
percretire234
# Out:
# Region     Education level 2
# Midwest    No degree             0.00
#            High School          25.00
#            Associate Degree     26.09
#            Bachelor Degree      33.33
#            Master Degree        40.00
# Northeast  No degree            14.29
#            High School          13.73
#            Associate Degree     16.67
#            Bachelor Degree      34.04
#            Master Degree        37.21
# South      No degree             4.17
#            High School           9.38
#            Associate Degree     17.02
#            Bachelor Degree      19.80
#            Master Degree        36.00
# West       No degree            30.00
#            High School          21.43
#            Associate Degree     36.36
#            Bachelor Degree      18.82
#            Master Degree        35.62
# dtype: float64

# %%
# visualizations

# %% [markdown]
# # Question 5: Does the overal education level influence investment participation?
# a. Are households with higher education levels more likely to hold a high avg value of stock mutual funds, tax-free bond mutual funds, government bond mutual funds, other bond mutual funds, combination mutual funds, other mutual funds

# %%
#based of fed avg and median data
fedavg=pd.read_csv(r"C:\Users\Owner\OneDrive\Documents\NSS\Capstone\Educationproj\data\interactive_bulletin_charts_edcl_mean.csv")
fedmedian=pd.read_csv(r"C:\Users\Owner\OneDrive\Documents\NSS\Capstone\Educationproj\data\interactive_bulletin_charts_edcl_median.csv")

# %%
#clean up data
#keep only 2022 rows
fedavg22=fedavg.loc[fedavg['year']== 2022]
fedmedian22=fedmedian.loc[fedmedian['year']== 2022]

# %%
fedavg22
# Out:
#     year                Category  Before_Tax_Income   Net_Worth      Assets  \
# 44  2022  No high school diploma          42.231964   175.62682   211.02757
# 45  2022     High school diploma          74.009827   413.27502   484.61728
# 46  2022            Some college          86.372299   540.87262   634.33282
# 47  2022          College degree         240.960280  1992.93540  2199.42480
#
#     Financial_Assets  Transaction_Accounts  Certificates_of_Deposit  \
# 44         40.250992              9.131320                58.384144
# 45        135.881420             23.384665                80.399956
# 46        202.245800             33.406494                70.465706
# 47       1032.491000            116.013540               120.399370
#
#     Savings_Bonds  Directly_Held_Bonds  ...  Other_Res_Real_Estate_Debt  \
# 44       3.941924            866.36090  ...                   54.632889
# 45      12.220004            527.18097  ...                   98.324966
# 46      16.288927            454.36673  ...                   87.986839
# 47      48.833744           1063.10770  ...                  330.532750
#
#     Installment_Loans  Other_Lines_of_Credit  Credit_Card_Balances  \
# 44          20.451849              10.191721              4.389903
# 45          24.675543             118.473630              4.760535
# 46          29.552080               7.275349              6.231104
# 47          50.942848             216.141040              7.270199
#
#     Other_Debt  Mortgages_Home_Equity_Loans  Home_Equity_Lines_of_Credit  \
# 44    5.465992                    129.42308                    41.499798
# 45    8.458094                    130.51874                    40.741398
# 46   13.791430                    171.28299                    40.539440
# 47  118.673450                    280.41827                    47.408401
#
#     Vehicle_Installment_Loans  Education_Installment_Loans  \
# 44                  17.253033                    12.246288
# 45                  20.354187                    34.388634
# 46                  21.245710                    31.972691
# 47                  22.474089                    58.654541
#
#     Other_Installment_Loans
# 44                12.752619
# 45                 7.306045
# 46                 7.087136
# 47                15.972934
#
# [4 rows x 37 columns]

# %%
#change No high school diploma
fedavg22['Category'] = fedavg22['Category'].replace("No high school diploma", "No degree")
fedmedian22['Category'] = fedmedian22['Category'].replace("No high school diploma", "No degree")
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_17128\3376109547.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fedavg22['Category'] = fedavg22['Category'].replace("No high school diploma", "No degree")
# C:\Users\Owner\AppData\Local\Temp\ipykernel_17128\3376109547.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fedmedian22['Category'] = fedmedian22['Category'].replace("No high school diploma", "No degree")

# %%
#educ_ref
#education for Q1
#make another col to match fmli eudcation level match fed uducation level
fededuclevel231=[]
for index, educ in fmli231.iterrows():
    if educ['EDUC_REF'] in {0,00,1,2,7,10,11}:
        fededuclevel231.append('No degree')
    elif educ['EDUC_REF'] in {3,4,12,}:
        fededuclevel231.append('High School')
    elif educ['EDUC_REF'] in {13,14}:
        fededuclevel231.append('Some College')
    elif educ['EDUC_REF'] in {5,6,15,16,17}:
        fededuclevel231.append('College Degree')
    else:
        fededuclevel231.append('N/A')
fmli231['Fed Education level']=fededuclevel231

# %%
#merge data on educ col
fedinvest22q1= pd.merge(fedavg22, fmli231, left_on='Category', right_on='Fed Education level', how='inner')

# %%
fedinvest22q1
# Out:
#      year   Category  Before_Tax_Income  Net_Worth     Assets  \
# 0    2022  No degree          42.231964  175.62682  211.02757
# 1    2022  No degree          42.231964  175.62682  211.02757
# 2    2022  No degree          42.231964  175.62682  211.02757
# 3    2022  No degree          42.231964  175.62682  211.02757
# 4    2022  No degree          42.231964  175.62682  211.02757
# ..    ...        ...                ...        ...        ...
# 373  2022  No degree          42.231964  175.62682  211.02757
# 374  2022  No degree          42.231964  175.62682  211.02757
# 375  2022  No degree          42.231964  175.62682  211.02757
# 376  2022  No degree          42.231964  175.62682  211.02757
# 377  2022  No degree          42.231964  175.62682  211.02757
#
#      Financial_Assets  Transaction_Accounts  Certificates_of_Deposit  \
# 0           40.250992               9.13132                58.384144
# 1           40.250992               9.13132                58.384144
# 2           40.250992               9.13132                58.384144
# 3           40.250992               9.13132                58.384144
# 4           40.250992               9.13132                58.384144
# ..                ...                   ...                      ...
# 373         40.250992               9.13132                58.384144
# 374         40.250992               9.13132                58.384144
# 375         40.250992               9.13132                58.384144
# 376         40.250992               9.13132                58.384144
# 377         40.250992               9.13132                58.384144
#
#      Savings_Bonds  Directly_Held_Bonds  ...  CHDTXPH  CHDTXPH_  FFTAXOWE  \
# 0         3.941924             866.3609  ...      NaN         A       483
# 1         3.941924             866.3609  ...      NaN         A      -592
# 2         3.941924             866.3609  ...      NaN         A    -12963
# 3         3.941924             866.3609  ...      NaN         A     -6600
# 4         3.941924             866.3609  ...      NaN         A      4399
# ..             ...                  ...  ...      ...       ...       ...
# 373       3.941924             866.3609  ...      NaN         A      5927
# 374       3.941924             866.3609  ...      NaN         A     -1167
# 375       3.941924             866.3609  ...      NaN         A    -16115
# 376       3.941924             866.3609  ...      NaN         A    -20370
# 377       3.941924             866.3609  ...      NaN         A     -4889
#
#      FSTAXOWE  FINATXEM     Region  Education level  Education level 2  \
# 0        4018  114529.2    Midwest  Bachelor Degree          No degree
# 1         236   22691.0  Northeast        No degree          No degree
# 2           0   66163.0      South      High School          No degree
# 3        -100   32734.0       West      High School          No degree
# 4        3412   80670.0    Midwest        No degree          No degree
# ..        ...       ...        ...              ...                ...
# 373         0   92073.0       West  Bachelor Degree          No degree
# 374         0   23462.2      South        No degree          No degree
# 375         0   36115.0      South        No degree          No degree
# 376     -1288   61458.0      South        No degree          No degree
# 377      1984   98747.6      South      High School          No degree
#
#      Income per Capita  Fed Education level
# 0         23500.400000            No degree
# 1         22335.000000            No degree
# 2          8866.666667            No degree
# 3         13017.000000            No degree
# 4         44240.500000            No degree
# ..                 ...                  ...
# 373       49000.000000            No degree
# 374       21400.000000            No degree
# 375        5000.000000            No degree
# 376        6633.333333            No degree
# 377        5440.000000            No degree
#
# [378 rows x 860 columns]

# %%
fedinvest22q1= fedinvest22q1[['year', 'Category','Pooled_Investment_Funds']]

# %%
fedinvest22q1.head()
# Out:
#    year   Category  Pooled_Investment_Funds
# 0  2022  No degree                103.45845
# 1  2022  No degree                103.45845
# 2  2022  No degree                103.45845
# 3  2022  No degree                103.45845
# 4  2022  No degree                103.45845

# %%
#get all unique values from category 
fedinvest22q1 = pd.DataFrame(fedinvest22q1['Category'].unique(), columns=['Category'])

# %%
fedinvest22q1.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[574], line 1
# ----> 1 fedinvest22q1.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
#fedinvest22q1= pd.merge(fedinvest22q1, fedmedian, left_on='Fed Education level', right_on='Category', how='inner')

# %% [markdown]
# # ASK CHRIS

# %% [markdown]
# # Are households with higher education levels less likely to have debt?
